# %% [markdown]
# # Webscraping
#
# > requests, BeautifulSoup
#
# - 구인구직 사이트 웹스크래핑
#
# > Indeed
# - https://kr.indeed.com/%EC%B7%A8%EC%97%85?as_and=python&as_phr=&as_any=&as_not=&as_ttl=&as_cmp=&jt=all&st=&salary=&radius=25&l=%EC%84%9C%EC%9A%B8&fromage=any&limit=50&sort=&psf=advsrch&from=advancedsearch
#
# > Stackoverflow

# %% [markdown]
# ## Indeed
#
# > 순서
# - 1) 모듈설치
# - 2) 가져올 페이지의 url요청 (get .text)
# - 3) 원하는 html 파트 가져오기 (Beautiful Soup)
# - 4) pagination 찾기
# - 5-1) pagination 안의 모든 앵커 찾기
# - 5-2) loop를 이용해 각 페이지의 "span" 모두 찾기
# - 6) 불러올 페이지 넘버 지정해주기
#
# > 참고
# - div : division (section 분할한다고 생각)
# - a : anchor (hyper link)

# %%
# 참고
# link(anchor)에서 string 추출해도 똑같은 결과가 나옴
# anchor가 있고, 이 요소 안에 다른 요소가 있고 그 요소에 string이 오직 하나 있다면 
# 그냥 anchor에서 string method 실행하면 됌
pages = []
for link in links[:-1]:
    pages.append(int(link.string))  # 그 안에 string만 가져오게 설정
                                    # int로 변경
max_page = pages[-1]

# %% [markdown]
# ### Indeed function
# - 위의 코드들과 나머지 코드들을 하나의 함수로 만듬
#
# > 참고 코드 링크
# - https://replit.com/@HJeongIn/Extracting-Indeed-Pages#indeed.py
#
# > 참고
# - 페이지 구조가 바뀌어서 다름
# - #2.5 댓글들 보면 많은 사람들이 해결법 올려줌 (참고)
#
# > Indeed의 [Jobs]
# - Step1. URL 가져오기
# - Step2. request 하기(to.서버)
# - Step3. Jobs 가져오기(정보 추출,Parsing)
# - 참고 - .string과 .text 차이 - https://www.inflearn.com/questions/3945

# %%
import requests
from bs4 import BeautifulSoup

Indeed_LIMIT = 50
Indeed_URL = "https://www.indeed.com/jobs?q=python&limit={}".format(Indeed_LIMIT)

# indeed 페이지 중 가장 마지막 페이지 return
def get_indeed_last_page():
    result = requests.get(Indeed_URL) # 실행시 에러 안 나오면 성공한 것임!
    soup = BeautifulSoup(result.text, "html.parser") # get을 통해 가져온 html document를 html.parser이용하여 쪼개기
    pagination = soup.find("div", {"class": "pagination"}) # class가 pagination인 html 가져와서 pagination에 저장
    links = pagination.find_all('a') # pagination html 속 모든! anchor(링크) 들을 리스트! 형태로 저장
    
    pages = [] # page 숫자들 저장할 List 
    for link in links[0:-1]: 
        pages.append(int(link.string)) 
    max_page = pages[-1] # 마지막 숫자 = 가장 큰 숫자
    return max_page

# job당 Title, Company, Location, ApplyLink로 정보 쪼개서 정리한 리스트 반환
def extract_indeed_job(html):
    title = html.select_one('.jobTitle>span').string #'new' 오류나는 title = html.find("h2", {"class":"jobTitle"}).find("span").string 대신 select_one 함수로!! 
    #<span> 속 title에 저장되어있는 job들 가져오기
    company = html.find("span", {"class":"companyName"}) # text내용을 가져와줄 .string #.string 안 해주면 html이 저장됨
    company_anchor = company.find("a") 
    #company 이름 중 링크(a)가 걸린 것도 아닌 것도 있음. 
    #company 정보가 <span>에 걸려 있는 경우와, <a>에 걸려 있는 찾아지는 경우가 나뉜다는 뜻
    if company_anchor is not None: # 링크(a)에 company 정보가 있는 경우
        company =str(company_anchor.string)  
    else:
        company = str(company.string) # 링크(a)에 없고 span에 company 정보가 있는 경우
    company = company.strip() # 빈 칸들 없애줌
    #print(title, company) 

    location = html.select_one("pre > div").text # 오류나는 html.find("div", {"class":"companyLocation"}).string 대신 select_one과 .text로!!!
    job_id = html.parent['data-jk'] # .parent 중요! 받아온 html의 부모 태그인 <a>에 [data-jk] 속성이 있음(사이트 업뎃 때문인듯)
    #print(job_id)# job_id는 지원링크의 id
    #print(location)
    #print(title)
    #print(result.status_code) # request가 last_page번 잘 되는지 확인해보는용
    return {
     'Title': title, 
     'Company': company, 
     'Location': location,
     'ApplyLnk': f"https://www.indeed.com/viewjob?jk={job_id}&from=web&vjs=3"
     }

# 해당 페이지의 모든 Job 추출
def extract_indeed_jobs(last_page):
    jobs = [] 
    for page in range(last_page): #page는 0부터 시작
        print("Scrapping Indeed Page : {}".format(page)) # 코드실행 진행여부 확인용
        result = requests.get("{0}&start={1}".format(Indeed_URL, page*Indeed_LIMIT)) #우리가 원하는 형태의 url로 request도 가능! 
        # 페이지 넘어갈 때마다! URL의 맨 뒤에 &limit={배열*50} 형태를 넣어준 상태에서 다음 페이지 request 해야함 #HTTP 통신상 한 URL씩 request해야 html 내용 가져올 수 있음
        soup = BeautifulSoup(result.text,"html.parser")
        results = soup.find_all("div", {"class":"slider_container"}) # 직업군 애용있는 html 가져오기

        for result in results:
            job = extract_indeed_job(result) # result은 html 저장중
            jobs.append(job)
    return jobs 

def get_indeed_jobs():
    last_indeed_pages = get_indeed_last_page()
    indeed_jobs = extract_indeed_jobs(last_indeed_pages)
    
    return indeed_jobs

# %%
get_indeed_jobs()
# Out:
# Scrapping Indeed Page : 0
# Scrapping Indeed Page : 1
# Scrapping Indeed Page : 2
# Scrapping Indeed Page : 3
# Scrapping Indeed Page : 4
# [{'Title': 'Python Developer',
#   'Company': 'Shuup Commerce Inc',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f9534ae0091f5310&from=web&vjs=3'},
#  {'Title': 'Backend Python Engineer',
#   'Company': 'Play Magnus',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c27f1c0f6f92cb2c&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'ShipHero',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1ef36fc836615b49&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer',
#   'Company': 'Double River Investments Limited',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bb1cf2320fd7fc69&from=web&vjs=3'},
#  {'Title': 'PYTHON DEVELOPER',
#   'Company': 'Pythonwise',
#   'Location': 'Seattle, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1a20a1c56fb7df73&from=web&vjs=3'},
#  {'Title': 'JUNIOR PYTHON DEVELOPER',
#   'Company': 'Solutions Resource',
#   'Location': 'Bellevue, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ad2bbe549fe4881c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Nexient',
#   'Location': 'Ann Arbor, MI 48108+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=37b2d4933fb25f5f&from=web&vjs=3'},
#  {'Title': 'Junior Python Developer',
#   'Company': 'GTS',
#   'Location': 'New York, NY 10022 (Midtown area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=71acc67a281f6038&from=web&vjs=3'},
#  {'Title': 'Junior Frontend Engineer',
#   'Company': 'The Veloz Group',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=be8ebda8ac2ae04f&from=web&vjs=3'},
#  {'Title': 'Python Software Engineering Teaching Assistant (Part-Time)',
#   'Company': 'Hackbright Academy',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cc10e115d1ed386e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'ESO',
#   'Location': 'Belcamp, MD',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=605b7c6764f51598&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Go8IT',
#   'Location': 'Plainsboro, NJ',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cb88227c76653ec9&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Outside Online',
#   'Location': 'Boulder, CO',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=896f0683f822304e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Highbrow-Tech',
#   'Location': 'Bellevue, WA+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=70912d7ae92ee088&from=web&vjs=3'},
#  {'Title': 'Desarrollador Backend Python',
#   'Company': 'Seeconds',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d0eb1294325cb3f1&from=web&vjs=3'},
#  {'Title': 'PYTHON/PhP SOFTWARE ENGINEER - Contract',
#   'Company': 'InspiHER Tech',
#   'Location': 'Indiana•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a145a678281087dc&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'eMoney Advisor',
#   'Location': '+9 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cf07a7088aaddbd6&from=web&vjs=3'},
#  {'Title': 'Entry Level Business Analyst-Remote',
#   'Company': 'Agama Solutions',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6f6a1c18da31655b&from=web&vjs=3'},
#  {'Title': 'PYTHON DEVELOPER',
#   'Company': 'OC10',
#   'Location': 'Charlotte, NC 28202 (Downtown Charlotte area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f26b8209c93fdd28&from=web&vjs=3'},
#  {'Title': 'Data Analyst- Spring 2022',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=de5d4f8bf8cd486d&from=web&vjs=3'},
#  {'Title': 'Remote Operations & Support Specialist',
#   'Company': 'Netflix',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a67febf94f1a5207&from=web&vjs=3'},
#  {'Title': 'Python Developer Anywhere',
#   'Company': 'Santex Group',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=040f2c487a3dd6d3&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Saraca Solutions',
#   'Location': 'Harrisburg, PA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7a7f0d6cdbec9856&from=web&vjs=3'},
#  {'Title': 'Python Developer-Reactjs',
#   'Company': 'SmarTek21, LLC',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=034026350a31dc8e&from=web&vjs=3'},
#  {'Title': 'Data Engineer (Python, Pyspark, Airflow, AWS)',
#   'Company': 'Nexient',
#   'Location': 'Ann Arbor, MI 48108+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6ef270d4c698a818&from=web&vjs=3'},
#  {'Title': 'Python Engineer - Remote, Full Time',
#   'Company': 'Bluelight Consulting',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9a698878b37e8e50&from=web&vjs=3'},
#  {'Title': 'Python Developer-1',
#   'Company': 'TIAA',
#   'Location': 'New York State+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b736f44252e1d179&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Sara Technologies',
#   'Location': 'San Diego, CA 92127',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=07cc59a85ae4d228&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Moove-it',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=30d2deae65d78d38&from=web&vjs=3'},
#  {'Title': 'Acoustics and Vibration Engineer I (NX)',
#   'Company': 'Gulfstream Aerospace Corporation',
#   'Location': 'Savannah, GA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=84aabceb26b29595&from=web&vjs=3'},
#  {'Title': 'Software Developer – Entry Level',
#   'Company': 'Grant Street Group',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b8bfec599e550f11&from=web&vjs=3'},
#  {'Title': 'Software Engineer- JS and Python',
#   'Company': 'SAP',
#   'Location': 'Bellevue, WA 98004 (Downtown area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2a2fdb6c6567f9c1&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Nuvento systems',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f2beba2d5640fd15&from=web&vjs=3'},
#  {'Title': 'Python Tester',
#   'Company': 'Accenture',
#   'Location': 'Redmond, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ee4976f2befef230&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Luxoft',
#   'Location': '+3 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=43cce086e1acd9a1&from=web&vjs=3'},
#  {'Title': 'Backend Python Engineer',
#   'Company': 'Numerator',
#   'Location': 'United States+10 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0d0b756b6441580c&from=web&vjs=3'},
#  {'Title': 'Experienced AWS Python Contractor',
#   'Company': 'stackbuilders',
#   'Location': 'New York, NY 10016 (Flatiron District area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7a6eb7709512853c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Value Info Tech',
#   'Location': 'Phoenix, AZ',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2fa1acf7705f32ea&from=web&vjs=3'},
#  {'Title': 'Senior Software Engineer (Back End - Python)',
#   'Company': 'Nearpod',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=92076d82b5b242ce&from=web&vjs=3'},
#  {'Title': 'Jr. Python Developer',
#   'Company': 'Kibo Commerce',
#   'Location': 'Dallas, TX 75201',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5ccd82b0221de315&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Snap IT Solutions',
#   'Location': 'Houston, TX 77099 (Alief area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0e10fe734c597c75&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Python (Entry-level)',
#   'Company': 'Kernel',
#   'Location': 'Culver City, CA 90232 (Jefferson area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bba24995ad8bfe29&from=web&vjs=3'},
#  {'Title': 'Python Software Engineer - Remote',
#   'Company': 'DXC Technology',
#   'Location': 'Tampa, FL+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3caadc51357c5314&from=web&vjs=3'},
#  {'Title': 'Sr. Python Engineer',
#   'Company': 'Highbrow-Tech',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b3082332444a0831&from=web&vjs=3'},
#  {'Title': 'Python, R Developer',
#   'Company': 'TCS',
#   'Location': 'Indianapolis, IN+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=312ea84743ff9ffb&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Novogradac & Company',
#   'Location': 'Portland, OR+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d2273b9ea4656f60&from=web&vjs=3'},
#  {'Title': 'Junior Engineer',
#   'Company': 'wpromote',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21ebe479a0b1ab2e&from=web&vjs=3'},
#  {'Title': 'Student Worker Part-time',
#   'Company': 'Wiley',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a7f73c389b5a704&from=web&vjs=3'},
#  {'Title': 'Senior Software Engineer (Python)',
#   'Company': 'EAB',
#   'Location': 'Birmingham, AL 35203+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a31c36e906eb13da&from=web&vjs=3'},
#  {'Title': 'Entry Level Software Developer',
#   'Company': 'Property Matrix',
#   'Location': 'Burbank, CA 91502 (Burbank Center area)+8 locations•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c91423d2223633c7&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Alertus',
#   'Location': 'Baltimore, MD 21202 (Inner Harbor area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cc72811ec0f43eda&from=web&vjs=3'},
#  {'Title': 'Web Engineer',
#   'Company': 'Airship',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=df6ccc4b8fbe8e8b&from=web&vjs=3'},
#  {'Title': 'Senior DevOps/SRE Engineer (Can work remotely)',
#   'Company': 'First American',
#   'Location': 'Folsom, CA 95630+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5ddd8a9361bbd9f8&from=web&vjs=3'},
#  {'Title': 'Senior ETL Developer (Python)',
#   'Company': 'Tista Science and Technology Corporation',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4583823af072236a&from=web&vjs=3'},
#  {'Title': 'Data Analyst',
#   'Company': 'Disney Streaming',
#   'Location': 'Santa Monica, CA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3ce68832dc2b5674&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Cumming Group',
#   'Location': 'San Francisco, CA 94111 (Financial District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=89e87dee7366d3b3&from=web&vjs=3'},
#  {'Title': 'Junior Readypipe Engineer I',
#   'Company': 'Yipit Inc.',
#   'Location': 'New York, NY+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6f2b8e2826281709&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Congruent Info-Tech',
#   'Location': 'Bellevue, WA 98007 (Lake Hills area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d3bed7cda41d9f8f&from=web&vjs=3'},
#  {'Title': 'Experienced Python/Django Contractor',
#   'Company': 'stackbuilders',
#   'Location': 'New York, NY 10016 (Flatiron District area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3ca8847c8187fe73&from=web&vjs=3'},
#  {'Title': 'Junior Python Developer',
#   'Company': 'Haynes Futures LLC',
#   'Location': 'Lorton, VA 22079',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=211996a23c2e5a66&from=web&vjs=3'},
#  {'Title': 'Software Developer, Python',
#   'Company': 'Vertical Knowledge',
#   'Location': 'Chagrin Falls, OH•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=621f947d91e7edd3&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'States United Democracy Center',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b166f8d88c2bcfa9&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'OMBU',
#   'Location': 'Portland, OR 97214 (Buckman area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d13b06d1113de40c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Sparibis',
#   'Location': 'Orlando, FL•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3612eb64bce6b034&from=web&vjs=3'},
#  {'Title': 'Jr. DevOps Engineer',
#   'Company': 'SkyHive Technologies Inc.',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a83943b190d2465c&from=web&vjs=3'},
#  {'Title': 'Python Application Developer (13844)',
#   'Company': 'Baer Group',
#   'Location': 'Alexandria, VA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=dd24745835022a3d&from=web&vjs=3'},
#  {'Title': 'Python Engineer - GS Accelerate',
#   'Company': 'Goldman Sachs',
#   'Location': 'Dallas, TX 75201 (Arts District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=801b64da973be520&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'New Jersey Institute of Technology',
#   'Location': 'Newark, NJ 07102 (Central Business District area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b75382f204d97cd8&from=web&vjs=3'},
#  {'Title': 'Jr. Python Developer',
#   'Company': 'Futrend Technology, Inc.',
#   'Location': 'Rockville, MD 20852',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5e3410c1d37f8e00&from=web&vjs=3'},
#  {'Title': 'Frontend Developer',
#   'Company': 'Red Acre',
#   'Location': 'Saint Julian, SC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46e5de74893924a9&from=web&vjs=3'},
#  {'Title': 'Software Engineer (Python)',
#   'Company': 'Sure',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e8b9807be9d1933e&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Python',
#   'Company': 'Backstage',
#   'Location': 'New York, NY•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2814f981b67e8b0b&from=web&vjs=3'},
#  {'Title': 'Entry Level Software Developer (Python)',
#   'Company': 'Columbus Technologies',
#   'Location': 'Pasadena, CA 91101 (West Central area)•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6c38d6f6235a4fdd&from=web&vjs=3'},
#  {'Title': 'Python Developer (Fullstack)',
#   'Company': 'Konviere Corporation',
#   'Location': 'Leawood, KS',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=213ef23aef1e09fd&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Infogen Labs',
#   'Location': 'Valencia, CA 91355',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b7b5a7c1d1027d10&from=web&vjs=3'},
#  {'Title': 'Frontend Engineer, University Graduate - 2022 Start',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7423e56c5d5a069d&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Taflink Care',
#   'Location': 'Dallas, TX•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e589a87aed9e899f&from=web&vjs=3'},
#  {'Title': 'Algorithms Engineer',
#   'Company': 'Double River Investments Limited',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b8876bb1eba675ff&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer (Junior)',
#   'Company': 'Nexient',
#   'Location': 'Columbus, OH+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a1a2a840cfa23f90&from=web&vjs=3'},
#  {'Title': 'Software Engineer (Backend)',
#   'Company': 'Textio',
#   'Location': 'Seattle, WA 98104+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e711a7b12acdcaef&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Capgemini',
#   'Location': 'Burbank, CA+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=921379330a10ad90&from=web&vjs=3'},
#  {'Title': 'Online Coding Instructor (Remote)',
#   'Company': 'CodeCombat',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21ffebdf3906d3a6&from=web&vjs=3'},
#  {'Title': 'Systems Modeling Engineer',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a184ec203496dbac&from=web&vjs=3'},
#  {'Title': 'Python Software Development Engineer',
#   'Company': 'Reynolds and Reynolds',
#   'Location': 'Austin, TX 73301 (St Edwards area)+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4cd3307fd2fb5343&from=web&vjs=3'},
#  {'Title': 'GIS Technician',
#   'Company': 'Flo Analytics',
#   'Location': 'Seattle, WA+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b5e9951b5f0dfff4&from=web&vjs=3'},
#  {'Title': 'Lead Python Engineer',
#   'Company': 'S&P Global',
#   'Location': 'Lansing, MI 48901+45 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9d24af4c2937ade7&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Mati',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ad23e3098da93091&from=web&vjs=3'},
#  {'Title': 'Data Scientist - Entry Level',
#   'Company': 'Numerdox',
#   'Location': 'Sacramento, CA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3dde0133818987f0&from=web&vjs=3'},
#  {'Title': 'Economist - Full Time Opportunities 2022',
#   'Company': 'Wayfair',
#   'Location': 'Boston, MA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3f53429744bc60a9&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Fusion Genius',
#   'Location': 'Alameda, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=374a0913cfa1f9f8&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'SugarCRM',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0b05c2ae25b651c4&from=web&vjs=3'},
#  {'Title': 'Ground Software — Associate Engineer (Summer 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a0ce5b3529fdd4b0&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Advaiya',
#   'Location': 'Bellevue, WA 98007 (Overlake area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9ccb06a74de52829&from=web&vjs=3'},
#  {'Title': 'Sr. Systems Engineer',
#   'Company': "Aaron's",
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a5f9ae893deba38c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'The Oakleaf Group',
#   'Location': 'Washington, DC 20010 (Columbia Heights area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1f466da47bdedea7&from=web&vjs=3'},
#  {'Title': 'Python Engineer - Banking Platform Team',
#   'Company': 'Avant',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7f97b256c3c7e391&from=web&vjs=3'},
#  {'Title': 'Associate Data Engineer (SQL, Cognos, Python)',
#   'Company': 'Travelers',
#   'Location': 'Saint Paul, MN+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cd4214a1630c5904&from=web&vjs=3'},
#  {'Title': 'CS152 Introduction to Python Programming',
#   'Company': 'Park University Adjuncts',
#   'Location': 'San Antonio, TX 78236+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b1fa32e276038be3&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'magnitude',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0579faf2b17d7b9d&from=web&vjs=3'},
#  {'Title': 'Programming Staff Writer',
#   'Company': 'Valnet Freelance',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=18806c0298c50194&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'magnitude',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0579faf2b17d7b9d&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Fusion Genius',
#   'Location': 'Alameda, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=374a0913cfa1f9f8&from=web&vjs=3'},
#  {'Title': 'Associate Data Engineer (SQL, Cognos, Python)',
#   'Company': 'Travelers',
#   'Location': 'Saint Paul, MN+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cd4214a1630c5904&from=web&vjs=3'},
#  {'Title': 'Python Backend Developer (Remote)',
#   'Company': 'Parlance',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c2437828c44a5ef9&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'SugarCRM',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0b05c2ae25b651c4&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Advaiya',
#   'Location': 'Bellevue, WA 98007 (Overlake area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9ccb06a74de52829&from=web&vjs=3'},
#  {'Title': 'Entry-Level Test Engineer',
#   'Company': 'BOEING',
#   'Location': 'Smithfield, PA+7 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=be0585fd4414d72b&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer',
#   'Company': 'SPECTRIO LLC',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=320e0ca0515f2896&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'Wayne State University',
#   'Location': 'Detroit, MI',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7780e19564c00c07&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Saama Technologies Inc',
#   'Location': 'Bridgewater, NJ 08807',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=88a47b061b02935b&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Cowbell Cyber Inc.',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d761077ec64c4aae&from=web&vjs=3'},
#  {'Title': 'Junior DevOps Engineer',
#   'Company': 'Deloitte',
#   'Location': 'Mechanicsburg, PA 17050+107 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a9066c895a1041a9&from=web&vjs=3'},
#  {'Title': 'Backend Software Engineer-TikTok',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+16 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=523fdbe809b6c2f2&from=web&vjs=3'},
#  {'Title': 'Marketing & Sales Transformation Data Scientist',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c06e6776bec13016&from=web&vjs=3'},
#  {'Title': 'Middle Python Developer',
#   'Company': 'AgileEngine',
#   'Location': 'Grow, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f38bbe4b9c599f58&from=web&vjs=3'},
#  {'Title': 'Economist - Full Time Opportunities 2022',
#   'Company': 'Wayfair',
#   'Location': 'Boston, MA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3f53429744bc60a9&from=web&vjs=3'},
#  {'Title': 'Backend Engineer, Perception',
#   'Company': 'Snapchat',
#   'Location': 'Los Angeles, CA 90291 (Venice area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ae4f23b48d0d4026&from=web&vjs=3'},
#  {'Title': 'Python Developer - US',
#   'Company': 'Perceptive Analytics',
#   'Location': 'Houston, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=09b67070d526895b&from=web&vjs=3'},
#  {'Title': 'Entry-Level Software Engineer',
#   'Company': 'Motorola Solutions',
#   'Location': 'Schaumburg, IL+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=841ef5765d47f4c3&from=web&vjs=3'},
#  {'Title': 'Systems Modeling Engineer',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a184ec203496dbac&from=web&vjs=3'},
#  {'Title': 'Backend Engineer',
#   'Company': 'Sila Inc.',
#   'Location': 'Portland, OR 97204+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=aed5f7a2e8779c56&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Dyno Nobel',
#   'Location': 'Salt Lake City, UT 84121',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8a7cc0dd2929e87e&from=web&vjs=3'},
#  {'Title': 'Python Dev / Analyst',
#   'Company': 'Fuego Leads',
#   'Location': 'Columbus, OH 43215 (Downtown area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=71da39d9833d51ad&from=web&vjs=3'},
#  {'Title': 'Network Engineer (with Python Scripting)',
#   'Company': 'Pinnacle Group',
#   'Location': 'Plano, TX+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fee44d88e55ab5e0&from=web&vjs=3'},
#  {'Title': 'Associate, YouTube',
#   'Company': 'YouTube',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a19d5d6e71bffeee&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Convazant',
#   'Location': 'Sunnyvale, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3bd86e0ab712b364&from=web&vjs=3'},
#  {'Title': 'JR. Engineer',
#   'Company': 'Nickelodeon Animation',
#   'Location': 'Burbank, CA 91502 (Burbank Center area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46df9ed5428cd34c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Stier Solutions',
#   'Location': 'Westlake Village, CA 91361',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b2de55596c3a1f9e&from=web&vjs=3'},
#  {'Title': 'Developer (Remote)',
#   'Company': 'The Hartford',
#   'Location': 'Texas•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=50995584da0eeb17&from=web&vjs=3'},
#  {'Title': 'Entry-Level Computer Engineer',
#   'Company': 'Opal Kelly',
#   'Location': 'Portland, OR 97223',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a2e8830485cc2dd9&from=web&vjs=3'},
#  {'Title': 'Python Data Engineer',
#   'Company': 'Intone Networks',
#   'Location': '+4 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a282c9a20dc750af&from=web&vjs=3'},
#  {'Title': 'Middle/Senior Python Developer',
#   'Company': 'ScienceSoft USA Corporation',
#   'Location': 'McKinney, TX 75070',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=483f2eac5b38d2e8&from=web&vjs=3'},
#  {'Title': 'Site Reliability Engineer - TikTok',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+38 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46ce5c48a3dee160&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Kinect',
#   'Location': 'El Segundo, CA 90245',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c6a0e156fd8d9f08&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Quality',
#   'Company': 'Benchling',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c9f2e404687688ff&from=web&vjs=3'},
#  {'Title': 'Senior Full-stack Software Engineer - Javascript / Python /...',
#   'Company': 'Flexbox',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a82777950654f98&from=web&vjs=3'},
#  {'Title': 'Junior Backend Engineer',
#   'Company': 'AlphaFlow',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a189a6c81fbcd33b&from=web&vjs=3'},
#  {'Title': 'Junior Full Stack Engineer',
#   'Company': 'InnovaSystems International, LLC',
#   'Location': 'San Diego, CA 92108 (Mission Valley East area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2b2cd03c5b901051&from=web&vjs=3'},
#  {'Title': 'Python Developer - US Bank',
#   'Company': 'Globant',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e239b1dd44713ead&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Python',
#   'Company': 'Kandji',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0a8e299b63defaa8&from=web&vjs=3'},
#  {'Title': 'Software Analyst Apprentice',
#   'Company': 'Apprenti',
#   'Location': 'Milwaukee, WI',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=72e8b026db557a82&from=web&vjs=3'},
#  {'Title': 'Research Engineer Co-op',
#   'Company': 'Motorola Solutions',
#   'Location': 'Somerville, MA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fb907d3882a0540f&from=web&vjs=3'},
#  {'Title': '2021',
#   'Company': 'Chicago Transit Authority',
#   'Location': 'Chicago, IL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4f26544963a8ddec&from=web&vjs=3'},
#  {'Title': 'Remote - Conversational AI Engineer - Python Developer',
#   'Company': 'Ally Financial',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e2a7ca035ab3cd1a&from=web&vjs=3'},
#  {'Title': 'Full-Stack Python Software Developer',
#   'Company': 'Advanced Energy Economy',
#   'Location': '+3 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=170985c7d039ee10&from=web&vjs=3'},
#  {'Title': 'Digital Security Engineer',
#   'Company': 'Red Bull',
#   'Location': 'Santa Monica, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=09ee228ccc9dcf1f&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Clairvoyant',
#   'Location': 'Chandler, AZ 85226+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c863b057044219e8&from=web&vjs=3'},
#  {'Title': 'Senior React Developer',
#   'Company': 'eMoney Advisor',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cac29f5a382ee440&from=web&vjs=3'},
#  {'Title': 'Associate Data Scientist (Remote)',
#   'Company': 'The Hartford',
#   'Location': 'Charlotte, NC+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=926475797ba0525b&from=web&vjs=3'},
#  {'Title': 'Senior Data Scientist',
#   'Company': 'Schnucks',
#   'Location': 'St. Louis, MO 63146',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8fd43c7ca95087dd&from=web&vjs=3'},
#  {'Title': 'Associate Data Scientist (Remote)',
#   'Company': 'The Hartford',
#   'Location': 'Charlotte, NC+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=926475797ba0525b&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Kibo Commerce',
#   'Location': 'Dallas, TX 75201',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=31915b12b32bc7a9&from=web&vjs=3'},
#  {'Title': 'Remote - Conversational AI Engineer - Python Developer',
#   'Company': 'Ally Financial',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e2a7ca035ab3cd1a&from=web&vjs=3'},
#  {'Title': 'Digital Security Engineer',
#   'Company': 'Red Bull',
#   'Location': 'Santa Monica, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=09ee228ccc9dcf1f&from=web&vjs=3'},
#  {'Title': 'Fellow, Baseball Research & Development',
#   'Company': 'Cleveland Indians - Baseball Operations',
#   'Location': 'Ohio•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3b702780b7916f79&from=web&vjs=3'},
#  {'Title': 'Python Developer - Remote',
#   'Company': 'CentralSquare Technologies',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a8d66acff1b1e381&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Haneke Design',
#   'Location': 'Tampa, FL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=542b21736b6bca61&from=web&vjs=3'},
#  {'Title': 'Entry Software Engineer',
#   'Company': 'Datavant',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=792868e0104b4562&from=web&vjs=3'},
#  {'Title': 'Entry Level Systems Engineer',
#   'Company': 'BAE Systems',
#   'Location': 'San Diego, CA 92127 (Rancho Bernardo area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=290fa21bf9cf0110&from=web&vjs=3'},
#  {'Title': 'Robotic Systems Engineer',
#   'Company': 'Greenzie',
#   'Location': 'Atlanta, GA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=aa3aa1d1cdfd1490&from=web&vjs=3'},
#  {'Title': 'Software Developer (Entry Level)',
#   'Company': 'UltiSat',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0ae90fabaf5100df&from=web&vjs=3'},
#  {'Title': 'BI Manager - Digital Marketing',
#   'Company': 'Seer Interactive',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e2cf5a34833d0cac&from=web&vjs=3'},
#  {'Title': 'Python Software Engineer',
#   'Company': '3M',
#   'Location': 'Austin, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=dd76b213daa9e99f&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer, MLOps',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=22b32552f979ef4e&from=web&vjs=3'},
#  {'Title': 'Python with AWS Developer',
#   'Company': 'Hash Technologies',
#   'Location': 'Atlanta, GA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9bf965d9d2d4f2a5&from=web&vjs=3'},
#  {'Title': 'Java/Python Developer ( Remote)',
#   'Company': 'General Dynamics Information Technology',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0d5ca036a014c5b7&from=web&vjs=3'},
#  {'Title': 'SLAM and Perception Engineer',
#   'Company': 'Adaviv',
#   'Location': 'Somerville, MA 02143',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8415a52c6ef4b687&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Gelber Group LLC',
#   'Location': 'Chicago, IL 60654 (Near North area)•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8fdaed7e8a5d913f&from=web&vjs=3'},
#  {'Title': 'System Development Engineer – AWS Config, AWS Config',
#   'Company': 'Amazon.com Services LLC',
#   'Location': 'Seattle, WA+126 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=afb982d5d9e99619&from=web&vjs=3'},
#  {'Title': 'Software Engineer I',
#   'Company': 'IQVIA',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1f65fb5dbbe79c84&from=web&vjs=3'},
#  {'Title': 'IT Sr Data Scientist',
#   'Company': 'Save-A-Lot',
#   'Location': 'Saint Ann, MO 63074',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46709c4a0f3d76b9&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer',
#   'Company': 'Alloy',
#   'Location': 'New York, NY•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=813829bb6c109643&from=web&vjs=3'},
#  {'Title': 'AWS/Python Developer',
#   'Company': 'Accenture',
#   'Location': 'Hartford, CT 06103 (Downtown area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c04de165c70aead5&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer',
#   'Company': 'Lenovo',
#   'Location': 'Chicago, IL+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d0fde70ad6a4ceee&from=web&vjs=3'},
#  {'Title': 'Python and/or C++ Software Engineer',
#   'Company': 'JPMorgan Chase Bank, N.A.',
#   'Location': 'New York, NY+8 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3a5cbba15c31e2c1&from=web&vjs=3'},
#  {'Title': 'Propulsion — Associate Engineer (Spring 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b1060fd97370fbb6&from=web&vjs=3'},
#  {'Title': 'Analytics Engineer',
#   'Company': 'Outside Online',
#   'Location': 'Boulder, CO•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d1f21d4024e3fb5e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Fults & Associates',
#   'Location': 'Grapevine, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=724d43dd753723a7&from=web&vjs=3'},
#  {'Title': 'CG Layout Artist - Monsters at Work',
#   'Company': 'Disney Television Animation',
#   'Location': 'Glendale, CA (Grand Central area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=27a24ac46c92f42e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Palnar Transmedia',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fdb5a4e060506720&from=web&vjs=3'},
#  {'Title': 'Deep Learning Engineer/Scientist, Autopilot',
#   'Company': 'Tesla',
#   'Location': 'Palo Alto, CA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9f10697d88ff0253&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer (Remote)',
#   'Company': 'cloudteam',
#   'Location': 'Jacksonville, FL+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4dd5d1fe3064d4e0&from=web&vjs=3'},
#  {'Title': 'Trainee Software Engineer RRUS/928/2021',
#   'Company': 'EMIDS',
#   'Location': 'Franklin, TN 37064 (McEwen area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0cb511651e086582&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Python (BTU Analytics)',
#   'Company': 'FactSet Research Systems',
#   'Location': 'Lakewood, CO+7 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ed21b2e227f9aa61&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer, DevOps',
#   'Company': 'Ping Identity',
#   'Location': 'Denver, CO 80202 (Central Business District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=427b723d95f8bf4b&from=web&vjs=3'},
#  {'Title': 'Chargé de projets H/F',
#   'Company': 'CA Indosuez Wealth (Group)',
#   'Location': 'Miami, FL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=128e1dcdcf0c1c6e&from=web&vjs=3'},
#  {'Title': 'System Administrator',
#   'Company': '1st Light Energy',
#   'Location': 'Manteca, CA 95336',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d5d89849c0eaea34&from=web&vjs=3'},
#  {'Title': 'Entry level Data Engineer',
#   'Company': 'Certilytics',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e19d25beb10c61ac&from=web&vjs=3'},
#  {'Title': 'Data Analyst',
#   'Company': 'Hulu',
#   'Location': 'Santa Monica, CA 90404+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0cf36dc08e7e1810&from=web&vjs=3'},
#  {'Title': 'L1 Support - NORAM - Python Developer',
#   'Company': 'Jade Global',
#   'Location': 'San Jose, CA 95110 (North San Jose area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7650e6bff00fbe96&from=web&vjs=3'},
#  {'Title': 'Biomechanics Analyst, Baseball Research & Development',
#   'Company': 'Cleveland Indians - Baseball Operations',
#   'Location': 'Ohio•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=42420b58615467c7&from=web&vjs=3'},
#  {'Title': 'Senior Full Stack Python Developer (13794)',
#   'Company': 'Baer Group',
#   'Location': 'Washington, DC•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f038292e08467b86&from=web&vjs=3'},
#  {'Title': 'Test Development Engineer',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e84c3d80383cd0bd&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Extreme Engineering Solutions',
#   'Location': 'Verona, WI 53593',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=daf07c3b8f869f77&from=web&vjs=3'},
#  {'Title': 'Full Stack Developer',
#   'Company': 'Underdog.io',
#   'Location': 'New York, NY+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2df0564df7756395&from=web&vjs=3'},
#  {'Title': 'Software Quality & Customer Experience Engineer',
#   'Company': 'Hewlett Packard Enterprise',
#   'Location': 'Fort Collins, CO 80521+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9da9fef5fe09e501&from=web&vjs=3'},
#  {'Title': 'Software Quality Assurance Engineer',
#   'Company': 'OnlineMedEd',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=50f16bbe30d00820&from=web&vjs=3'},
#  {'Title': 'Software Engineer, University Graduate - 2022 Start',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+65 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21cc96f8ed47d56d&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Quip',
#   'Company': 'Salesforce',
#   'Location': '+78 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8caabd819729b588&from=web&vjs=3'},
#  {'Title': 'Python developer',
#   'Company': 'VAUXOO',
#   'Location': 'Colima, GA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f7669fcbd77ecd11&from=web&vjs=3'},
#  {'Title': 'Systems Engineer',
#   'Company': 'Snapchat',
#   'Location': 'Los Angeles, CA 90291 (Venice area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=364cf0f9d722572d&from=web&vjs=3'},
#  {'Title': 'Entry level Data Engineer',
#   'Company': 'Certilytics',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e19d25beb10c61ac&from=web&vjs=3'},
#  {'Title': 'Full Stack Developer',
#   'Company': 'Underdog.io',
#   'Location': 'New York, NY+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2df0564df7756395&from=web&vjs=3'},
#  {'Title': 'Python Developer (100% Remote)',
#   'Company': 'Denken Solutions Inc',
#   'Location': 'Alabama+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a60bb97c2e2d2ae1&from=web&vjs=3'},
#  {'Title': 'Trainee Software Engineer RRUS/928/2021',
#   'Company': 'EMIDS',
#   'Location': 'Franklin, TN 37064 (McEwen area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0cb511651e086582&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Quip',
#   'Company': 'Salesforce',
#   'Location': '+78 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8caabd819729b588&from=web&vjs=3'},
#  {'Title': 'Systems Programmer / Analyst',
#   'Company': 'Indiana University',
#   'Location': 'Bloomington, IN+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8ee506627f792237&from=web&vjs=3'},
#  {'Title': 'Python developer',
#   'Company': 'VAUXOO',
#   'Location': 'Colima, GA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f7669fcbd77ecd11&from=web&vjs=3'},
#  {'Title': 'Analytics Engineer',
#   'Company': 'Outside Online',
#   'Location': 'Boulder, CO•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d1f21d4024e3fb5e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Swan Software Solutions',
#   'Location': 'Carmel, IN',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=32eaa9e1e80e8c5d&from=web&vjs=3'},
#  {'Title': 'Software Engineer',
#   'Company': 'Hulu',
#   'Location': 'Santa Monica, CA+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=eafa191adae2c646&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Ivy Tech Solutions inc',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4acadd569ee3fb58&from=web&vjs=3'},
#  {'Title': 'Test Development Engineer',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e84c3d80383cd0bd&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Avani Systems',
#   'Location': 'Newark, DE',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2adef6dc99e86686&from=web&vjs=3'},
#  {'Title': 'Python Bootcamp Prep Instructor (Part-Time)',
#   'Company': 'Hackbright Academy',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d90877b5c3795182&from=web&vjs=3'},
#  {'Title': 'Python Developer with AWS',
#   'Company': 'JPMorgan Chase Bank, N.A.',
#   'Location': 'Jersey City, NJ+28 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e34af623c9f44fb1&from=web&vjs=3'},
#  {'Title': 'Fullstack Engineer (Carve Systems)',
#   'Company': 'iVision',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1250a0d52245eada&from=web&vjs=3'},
#  {'Title': 'Biomechanics Analyst, Baseball Research & Development',
#   'Company': 'Cleveland Indians - Baseball Operations',
#   'Location': 'Ohio•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=42420b58615467c7&from=web&vjs=3'},
#  {'Title': 'Chargé de projets H/F',
#   'Company': 'CA Indosuez Wealth (Group)',
#   'Location': 'Miami, FL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=128e1dcdcf0c1c6e&from=web&vjs=3'},
#  {'Title': 'Frontend Engineer',
#   'Company': 'Kyte',
#   'Location': 'San Francisco, CA+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=43d9c34f432dc4f1&from=web&vjs=3'},
#  {'Title': 'Data Scientist, Media Innovations',
#   'Company': 'The New York Times',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=56dfa4fb5edc37c4&from=web&vjs=3'},
#  {'Title': 'Test Automation Engineer',
#   'Company': 'Kpler',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0c7cc111c5a7ae8d&from=web&vjs=3'},
#  {'Title': 'Python/ ETL Tester',
#   'Company': 'Intone Networks',
#   'Location': 'Austin, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=085a7de8ddf9c330&from=web&vjs=3'},
#  {'Title': 'Analyst, DIG Growth (Games)',
#   'Company': 'The New York Times',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b929a38986a9bd98&from=web&vjs=3'},
#  {'Title': 'Front-End Engineer',
#   'Company': 'SAMBA TV',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=92efc35257c9a49d&from=web&vjs=3'},
#  {'Title': 'Entry Level Web Developer',
#   'Company': 'Motorola Solutions',
#   'Location': 'Schaumburg, IL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=370f3572b77f7a75&from=web&vjs=3'},
#  {'Title': 'Full Stacker Developer (100% Remote US-based)',
#   'Company': 'Cricket Media Services, Inc.',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bd7ef81ae80b8131&from=web&vjs=3'},
#  {'Title': 'Graduate Data Science, Analyst I - August 2022 - Seattle',
#   'Company': 'Expedia.com',
#   'Location': 'Seattle, WA 98119 (Queen Anne area)+12 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=722e513c7e657593&from=web&vjs=3'},
#  {'Title': 'Python Developer - Back End',
#   'Company': 'Deloitte',
#   'Location': 'Rosslyn, VA 22209 (Radnor-Ft Myer Heights area)+126 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=63823d6ee3ca9c19&from=web&vjs=3'},
#  {'Title': 'UX Engineer, Front End, Early Career',
#   'Company': 'Google',
#   'Location': 'San Francisco, CA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bce1cc9db3680333&from=web&vjs=3'},
#  {'Title': 'Entry Level Data Scientist: 2022',
#   'Company': 'IBM',
#   'Location': 'Research Triangle Park, NC 27709+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d9dc2b2ff8863e63&from=web&vjs=3'},
#  {'Title': 'Data & BI Engineer',
#   'Company': 'Fashion Group',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5c7305bc749d20da&from=web&vjs=3'},
#  {'Title': 'Python Development Lead (13843)',
#   'Company': 'Baer Group',
#   'Location': 'Alexandria, VA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=02acd56c3c900923&from=web&vjs=3'},
#  {'Title': 'Video Platform Engineer (Herndon, VA)',
#   'Company': 'Pexip',
#   'Location': 'Herndon, VA 20171',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=271155ce0a012751&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Machine Learning',
#   'Company': 'Benchling',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b129ad391a71ef83&from=web&vjs=3'},
#  {'Title': 'Radio Hardware — Associate Engineer (Spring/Summer 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e75569e6b749dfef&from=web&vjs=3'},
#  {'Title': 'Middle Python Developer',
#   'Company': 'Mobilunity',
#   'Location': 'United States+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=523fde45ae4cfa9a&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'ING',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=40802b7c00af44d8&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Recent/Upcoming Graduates',
#   'Company': 'Performance',
#   'Location': 'Clearwater, FL 33759+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9082517f4c6a700c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Morgan Stanley',
#   'Location': 'New York, NY+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=84c7ba71c316a022&from=web&vjs=3'},
#  {'Title': 'Junior Java /.Net /Python Developer',
#   'Company': 'Infosys',
#   'Location': 'Groton, CT•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4f16edb2c700c56a&from=web&vjs=3'},
#  {'Title': 'Research Data Analyst',
#   'Company': 'Daily Kos',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5cf6da7c0b03f782&from=web&vjs=3'},
#  {'Title': 'Operations Python Developer',
#   'Company': 'Hudson River Trading',
#   'Location': 'Austin, TX+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a01bb894b3c68e9&from=web&vjs=3'},
#  {'Title': 'Economist',
#   'Company': 'Amazon.com Services LLC',
#   'Location': 'Seattle, WA+15 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=983318b8073d1250&from=web&vjs=3'},
#  {'Title': 'Senior Manager, Data & Analytics',
#   'Company': 'Nutrien Ltd.',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=48498880ee6fe877&from=web&vjs=3'},
#  {'Title': 'Backend Developer (Python/MongoDB)',
#   'Company': 'Irisidea TechSolutions Pvt Ltd',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7fbef5b65dc94d34&from=web&vjs=3'},
#  {'Title': 'Remote Software Engineer',
#   'Company': 'Liberty Mutual Insurance',
#   'Location': '+4 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e0addae84f9f914f&from=web&vjs=3'},
#  {'Title': 'Python Programmer',
#   'Company': 'HedgeApple',
#   'Location': 'Lawrence, KS 66044',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3ef89ececeb2b081&from=web&vjs=3'},
#  {'Title': 'Python Developer :: 3 Months Contract to Hire :: Remote Role',
#   'Company': 'Agama Solutions',
#   'Location': 'San Francisco, CA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f6a64372a5851eec&from=web&vjs=3'},
#  {'Title': 'VR Artist',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2590bc51c44bc588&from=web&vjs=3'}]

# %% [markdown]
# ## StackOverflow
#
# > 순서
# - 1. 페이지 가져오기
# - 2. request 만들기
# - 3. extract the jobs

# %% [markdown]
# ### SO function
# > 자신의 User-Agent 보는 사이트
# - https://www.whatismybrowser.com/detect/what-is-my-user-agent

# %%
import requests
from bs4 import BeautifulSoup

SO_URL = "https://stackoverflow.com/jobs?q=python"
# 자신이 쓰는 브라우저와 똑같은 정보를 얻으려면, 해당 브라우저에 대한 정보를 인자값으로 입력
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36'}

def get_so_last_page():
    result = requests.get(SO_URL, headers = headers)
    soup = BeautifulSoup(result.text, "html.parser")
    pagination = soup.find('div', {'class':'s-pagination'})
    pages = pagination.find_all('a')
    pages = pages[:-1] # next 삭제
    last_page = pages[-1].get_text(strip=True)
    return int(last_page)
    

def extract_so_job(html):
    #title
    title = html.find('h2',{'class':'mb4'}).find('a')['title']
    #company, location
    company, location = html.find("h3", {"class":"fc-black-700"}).find_all('span', recursive = False) # 첫 단계 span만 가져옴
    company = company.get_text(strip=True)
    location = location.get_text(strip=True).strip('-').strip("\n")
    #job-id
    job_id = html['data-jobid']
    
    return {
        'title':title, 
        'company':company, 
        'location':location,
        'apply_link':"https://stackoverflow.com/jobs/{}".format(job_id)
    }
    
def extract_so_jobs(last_page):
    jobs = []
    for page in range(last_page):
        print("Scrapping StackOverflow Page : {}".format(page))
        result = requests.get("{0}&pg={1}".format(SO_URL,page+1))
        soup = BeautifulSoup(result.text, "html.parser")
        results = soup.find_all("div", {"class":"-job"})
        for result in results:
            job = extract_so_job(result)
            jobs.append(job)
    return jobs

def get_so_jobs():
    last_so_pages = get_so_last_page()
    so_jobs = extract_so_jobs(last_so_pages)
    
    return so_jobs

# %%
get_so_jobs()
# Out:
# Scrapping StackOverflow Page : 0
# Scrapping StackOverflow Page : 1
# Scrapping StackOverflow Page : 2
# Scrapping StackOverflow Page : 3
# Scrapping StackOverflow Page : 4
# Scrapping StackOverflow Page : 5
# Scrapping StackOverflow Page : 6
# Scrapping StackOverflow Page : 7
# Scrapping StackOverflow Page : 8
# [{'title': 'Python Software Engineer - Finance',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557258'},
#  {'title': 'Back-End Developer (i.e. Python)',
#   'company': 'Imaginary Cloud',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/557757'},
#  {'title': 'Python Software Engineer (Quant Trading Firm)',
#   'company': 'Old Mission Capital, LLC',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/528807'},
#  {'title': 'Senior Backend Engineer (Python/APIs)',
#   'company': 'Belvo Technologies',
#   'location': 'São Paulo, Brazil',
#   'apply_link': 'https://stackoverflow.com/jobs/552501'},
#  {'title': 'Python Entwickler*in Remote (f/m/d)',
#   'company': 'Ambient',
#   'location': 'Köln, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/493874'},
#  {'title': 'Python Full-Stack Software Engineer',
#   'company': 'Steeprock Inc',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/530560'},
#  {'title': 'Python Engineer',
#   'company': 'McD Tech Labs',
#   'location': 'Mountain View, CA',
#   'apply_link': 'https://stackoverflow.com/jobs/534766'},
#  {'title': 'Senior Backend Engineer - Python',
#   'company': 'Cornershop',
#   'location': 'São Paulo, Brazil',
#   'apply_link': 'https://stackoverflow.com/jobs/515697'},
#  {'title': 'Senior Software Developer Python (m/f/d)',
#   'company': 'Ströer Online Marketing',
#   'location': 'Hamburg, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/462625'},
#  {'title': 'Backend Engineer (Python/ Django)',
#   'company': 'Sector Labs',
#   'location': 'Dubai, United Arab Emirates',
#   'apply_link': 'https://stackoverflow.com/jobs/518496'},
#  {'title': 'Full Stack Developer (Python / React)',
#   'company': 'Elorus',
#   'location': 'Athens, Greece',
#   'apply_link': 'https://stackoverflow.com/jobs/551867'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556790'},
#  {'title': 'Backend Engineer (Python)',
#   'company': 'Zattoo',
#   'location': 'Berlin, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/556298'},
#  {'title': 'Software Engineer- Python',
#   'company': 'Engooden Health',
#   'location': 'Framingham, MA',
#   'apply_link': 'https://stackoverflow.com/jobs/556005'},
#  {'title': 'Software Engineer (Python or C++)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556713'},
#  {'title': 'Python Developer (Remote)',
#   'company': 'Finsera',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/524065'},
#  {'title': 'Python Software Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557845'},
#  {'title': 'Python Software Developer',
#   'company': 'EODC GmbH',
#   'location': 'Wien, Österreich',
#   'apply_link': 'https://stackoverflow.com/jobs/496568'},
#  {'title': 'Senior Software Engineer (Python)',
#   'company': 'HENNGE K.K.',
#   'location': 'Tokyo, Japan',
#   'apply_link': 'https://stackoverflow.com/jobs/555511'},
#  {'title': 'Backend Software Engineer: Python/ Java (m/f/d)',
#   'company': 'creditshelf',
#   'location': 'Frankfurt am Main, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/219940'},
#  {'title': '(Senior) Backend Python Developer (m/f/x)',
#   'company': 'Alasco',
#   'location': 'München, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/388312'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556058'},
#  {'title': 'Tech Lead, Python Systems Engineering',
#   'company': 'McD Tech Labs',
#   'location': 'Mountain View, CA',
#   'apply_link': 'https://stackoverflow.com/jobs/523801'},
#  {'title': 'Senior Python Software Engineer with SQL',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556364'},
#  {'title': 'C++ and Python software engineers - Metrology',
#   'company': 'ASML',
#   'location': 'Veldhoven, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/523429'},
#  {'title': 'Senior Python Engineer - Equities Prime - London',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556625'},
#  {'title': 'Senior Python developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557550'},
#  {'title': 'Software Engineer - Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558475'},
#  {'title': 'Lead/Senior Software Engineer (Python/Django)',
#   'company': 'Sector Labs',
#   'location': 'Dubai, United Arab Emirates',
#   'apply_link': 'https://stackoverflow.com/jobs/551454'},
#  {'title': 'Senior Software Engineer (Back End) - Python, Flask, Sqlalchemy, Redis-queue',
#   'company': 'Capital Group',
#   'location': 'Los Angeles, CA',
#   'apply_link': 'https://stackoverflow.com/jobs/538624'},
#  {'title': 'Senior Python/Django Full-stack Developer',
#   'company': 'Apicbase Belgium',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/545356'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557085'},
#  {'title': 'Senior Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/558329'},
#  {'title': 'Back-End Developer (i.e. Python)',
#   'company': 'Imaginary Cloud',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/557757'},
#  {'title': 'Software Engineer - Python',
#   'company': 'Hearst Magazines',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/485603'},
#  {'title': 'Software Engineer - Full Stack (React, Java, Python)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557417'},
#  {'title': 'Python Software Engineer',
#   'company': 'Captivation Software',
#   'location': 'Fort Meade, MD',
#   'apply_link': 'https://stackoverflow.com/jobs/525426'},
#  {'title': 'Senior Python Backend Developer',
#   'company': 'Alfi Inc.',
#   'location': 'Belfast, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/520640'},
#  {'title': 'Python Engineer',
#   'company': 'Secfi',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/473458'},
#  {'title': 'Software Engineer - Python/C++',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555048'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/555350'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558130'},
#  {'title': 'Full-Stack Engineer (Python OR Javascript)',
#   'company': 'Neo4j',
#   'location': 'Malmö, Sweden',
#   'apply_link': 'https://stackoverflow.com/jobs/362199'},
#  {'title': 'Commodities/Currencies/Emerging Markets Software Engineer - Athena Python platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555785'},
#  {'title': 'Senior Python/Django Full-stack Developer',
#   'company': 'Apicbase Belgium',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/515716'},
#  {'title': 'Full Stack Software Engineer (Java, Scala, Python) - Corporate Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558348'},
#  {'title': 'Senior Software Engineer - Python',
#   'company': 'DIGARC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/497630'},
#  {'title': 'Software Engineer-Java-Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558385'},
#  {'title': 'Python Entwickler*in Remote (f/m/d)',
#   'company': 'Ambient',
#   'location': 'Köln, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/493874'},
#  {'title': 'Java/Python Software Engineer (SQL/Database Design)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556645'},
#  {'title': 'Full Stack Software Engineer (Java, Scala, Python) - Corporate Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558348'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557085'},
#  {'title': 'Python Backend Engineer',
#   'company': 'Skillhouse Staffing Solutions',
#   'location': 'Tokyo, Japan',
#   'apply_link': 'https://stackoverflow.com/jobs/556016'},
#  {'title': 'Senior Python Backend Developer',
#   'company': 'Alfi Inc.',
#   'location': 'Belfast, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/520640'},
#  {'title': 'Python Developer (Remote)',
#   'company': 'X-Team',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/534454'},
#  {'title': 'Senior Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/558329'},
#  {'title': 'Python Engineer',
#   'company': 'Secfi',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/473458'},
#  {'title': 'Software Engineer - Python/C++',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555048'},
#  {'title': 'Java or Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'apply_link': 'https://stackoverflow.com/jobs/557965'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558130'},
#  {'title': 'SENIOR FULL-STACK DEV WITH RUBY / PYTHON / REACT NATIVE -- 100% REMOTE, FLEXIBLE',
#   'company': 'Analytics Fire',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/517987'},
#  {'title': 'Commodities/Currencies/Emerging Markets Software Engineer - Athena Python platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555785'},
#  {'title': 'Python Software Engineer - Global Rates Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556861'},
#  {'title': 'Senior Python/Django Full-stack Developer',
#   'company': 'Apicbase Belgium',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/515716'},
#  {'title': 'Python Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/555350'},
#  {'title': 'Software Engineering - Python - Athena Platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555394'},
#  {'title': 'Senior Software Engineer - Python',
#   'company': 'DIGARC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/497630'},
#  {'title': 'Senior Python Engineer - CIB Rates Products',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557545'},
#  {'title': 'Data Engineer for George #python (all genders)',
#   'company': 'Erste Group',
#   'location': 'Wien, Österreich',
#   'apply_link': 'https://stackoverflow.com/jobs/556540'},
#  {'title': 'Senior Python Engineer - Equities Prime - London',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556625'},
#  {'title': 'Java/Python Software Engineer (SQL/Database Design)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556645'},
#  {'title': 'Full-Stack Python Software Developer',
#   'company': 'Advanced Energy Economy',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/555893'},
#  {'title': 'Principal Python Engineer',
#   'company': 'ComplyAdvantage',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/504216'},
#  {'title': 'VP Python Engineering Manager (Securities Services)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557849'},
#  {'title': 'Data Engineer (Python, SQL)',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/526406'},
#  {'title': 'Software Engineer - Full Stack (React, Java, Python)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557417'},
#  {'title': 'Python Back End Developer (FastAPI, Django, Celery)',
#   'company': 'Daupler, Inc.',
#   'location': 'Kansas City, MO',
#   'apply_link': 'https://stackoverflow.com/jobs/523350'},
#  {'title': 'Senior Developer (Python/React) -  FO Marking and Analytics',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556835'},
#  {'title': '(Junior) Software Developer Python (m/w/d)',
#   'company': 'Univention GmbH',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/550381'},
#  {'title': 'Technical Lead (Python/C++) Engineer - Realtime Data Services',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/558166'},
#  {'title': 'Python Software Engineer - Global Rates Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556861'},
#  {'title': 'Software Engineering - Python - Athena Platform',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555394'},
#  {'title': 'Python Developer',
#   'company': 'Zyte (formerly Scrapinghub)',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/513698'},
#  {'title': 'Senior Data Engineer (Python, Kafka, Airflow)',
#   'company': 'AMBOSS',
#   'location': 'Berlin, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/415218'},
#  {'title': 'Junior IoT Developer (M/W/D) Python, C++',
#   'company': 'VISPIRON CHARGE-V GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/548810'},
#  {'title': 'Python Software Engineer (Linux, Security)',
#   'company': 'diconium group',
#   'location': 'Stuttgart, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/556429'},
#  {'title': 'HA Proxy-Java/Python Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555014'},
#  {'title': 'Senior Python Developer - Django Rest Framework',
#   'company': 'n.exchange',
#   'location': 'Lisbon, Portugal',
#   'apply_link': 'https://stackoverflow.com/jobs/554539'},
#  {'title': 'Python Developer',
#   'company': 'Risk Focus',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/552173'},
#  {'title': 'Senior Python/Django Full-stack Developer',
#   'company': 'Apicbase Belgium',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/515716'},
#  {'title': 'Senior Python Backend Developer',
#   'company': 'Alfi Inc.',
#   'location': 'Belfast, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/520640'},
#  {'title': 'Software Engineer - Python/C++',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555048'},
#  {'title': 'Python Software Engineer',
#   'company': 'Sav.com',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/515692'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'Boston, MA',
#   'apply_link': 'https://stackoverflow.com/jobs/524663'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557178'},
#  {'title': 'Sr Full Stack Software Engineer (Python/React/AWS)',
#   'company': 'Carex Consulting GroupviaCarex Consulting Group',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/546570'},
#  {'title': 'Senior Python Engineer - Base Metals Team Lead',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558233'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558130'},
#  {'title': 'Equities Front Office Python Developer & Team Lead',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556686'},
#  {'title': 'Associate Equity Athena Intraday Risk (Python, React/TS)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557142'},
#  {'title': 'Software Engineer (Python and/or C++) - Commodities',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556714'},
#  {'title': 'Python Developer',
#   'company': 'Risk Focus',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/552173'},
#  {'title': 'Senior Python/Django Full-stack Developer',
#   'company': 'Apicbase Belgium',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/515716'},
#  {'title': 'VP Equity Finance Technical Lead (Python Software Engineering, Architecture, Quant-Dev)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557905'},
#  {'title': 'Python/Java Infrastructure Developer - Data Protection',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557068'},
#  {'title': 'Senior Python Backend Developer',
#   'company': 'Alfi Inc.',
#   'location': 'Belfast, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/520640'},
#  {'title': 'Software Engineer - Python/C++',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555048'},
#  {'title': 'Python Software Engineer',
#   'company': 'Sav.com',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/515692'},
#  {'title': 'Senior IoT Developer (M/W/D/) Python, C++',
#   'company': 'VISPIRON CHARGE-V GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/524044'},
#  {'title': 'Senior Python Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'Boston, MA',
#   'apply_link': 'https://stackoverflow.com/jobs/524663'},
#  {'title': 'Senior Developer (Python/React) -  FO Marking and Analytics',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556835'},
#  {'title': 'Technical Lead (Python/C++) Engineer - Realtime Data Services',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/558166'},
#  {'title': 'Senior Python Engineer - Base Metals Team Lead',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558233'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558130'},
#  {'title': 'Python Software Engineer (Cloud/Data Science)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557672'},
#  {'title': 'Python Software Engineer - Global Rates Technology - Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557227'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557178'},
#  {'title': 'Sr Full Stack Software Engineer (Python/React/AWS)',
#   'company': 'Carex Consulting GroupviaCarex Consulting Group',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/546570'},
#  {'title': 'Senior Data Engineer (Python, Kafka, Airflow)',
#   'company': 'AMBOSS',
#   'location': 'Berlin, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/415218'},
#  {'title': 'Senior Software Engineer - Python',
#   'company': 'DIGARC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/497630'},
#  {'title': 'Senior Cloud Developer - AWS / Cloud Foundry / Java / Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'apply_link': 'https://stackoverflow.com/jobs/555405'},
#  {'title': 'Python Software Engineering - Cloud Technologies',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556977'},
#  {'title': 'Senior Software Engineer, Integration QA, Python',
#   'company': 'Canonical',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/519661'},
#  {'title': 'Java/Python Software Engineer (SQL/Database Design)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556645'},
#  {'title': 'Senior Python Developer',
#   'company': 'GeoPhy',
#   'location': 'Den Haag, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/552144'},
#  {'title': 'Senior Backend Python Engineer - Applied AI Systems - London',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558322'},
#  {'title': 'Python Software Engineer - Athena Market Data',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557505'},
#  {'title': 'Site Reliability Engineer - Associate - Python, AWS/GCP - Flexible Working',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557177'},
#  {'title': 'Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/556734'},
#  {'title': 'Python Software Engineer (Cloud)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555388'},
#  {'title': 'Software Engineering - Java Developer (with Python, Linux and Oracle/SQL DB exp)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557956'},
#  {'title': 'Software Engineer - AI Team (Java, Python, AWS)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557557'},
#  {'title': 'Python Software Engineer - Global Rates Technology - Associate',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Glasgow, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557227'},
#  {'title': 'Software Engineer (Python and/or C++) - Commodities',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556714'},
#  {'title': 'Python/Java developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557549'},
#  {'title': 'Fullstack Cloud Engineer (Python/React/AWS)',
#   'company': 'Montash',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/556128'},
#  {'title': 'Python Software Engineering - Cloud Technologies',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556977'},
#  {'title': 'Senior Software Engineer (Java/Python - Data Insights)',
#   'company': 'ComplyAdvantage',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/528607'},
#  {'title': 'Senior Python Developer',
#   'company': 'GeoPhy',
#   'location': 'Den Haag, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/552144'},
#  {'title': 'Data Engineer - Python',
#   'company': 'Capital Group',
#   'location': 'Irvine, CA',
#   'apply_link': 'https://stackoverflow.com/jobs/538626'},
#  {'title': 'Python Developer suchen Kollegen (m/w/d)',
#   'company': 'solute GmbH',
#   'location': 'Karlsruhe, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/284443'},
#  {'title': 'CIB - Quantitative Research - Market Risk - Associate - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557829'},
#  {'title': 'Fullstack Developer (Python/React)',
#   'company': 'We Got POP Ltd',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/525267'},
#  {'title': 'Python Developer/ Trading Systems Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522467'},
#  {'title': 'VP - Python Infrastructure Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/558226'},
#  {'title': 'SENIOR FULL-STACK DEV WITH RUBY / PYTHON / REACT NATIVE -- 100% REMOTE, FLEXIBLE',
#   'company': 'Analytics Fire',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/517987'},
#  {'title': 'Software Engineer (Java, Python) - Product Tooling',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/555919'},
#  {'title': 'Python/Cloud Software Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557661'},
#  {'title': 'Java/Python Software Engineer (SQL/Database Design)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556199'},
#  {'title': 'Python Data Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557686'},
#  {'title': 'Java/Python Software Engineer (SQL/Database Design)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556199'},
#  {'title': 'Python Developer/ Trading Systems Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522467'},
#  {'title': 'VP - Python Infrastructure Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/558226'},
#  {'title': 'SENIOR FULL-STACK DEV WITH RUBY / PYTHON / REACT NATIVE -- 100% REMOTE, FLEXIBLE',
#   'company': 'Analytics Fire',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/517987'},
#  {'title': 'Software Engineer (Java, Python) - Product Tooling',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/555919'},
#  {'title': 'Python Developer/ Data Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522466'},
#  {'title': 'Python Data Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557686'},
#  {'title': 'Senior Python Engineer - Athena Trade & Risk Services - Instrument & Lifecycle Group -...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558321'},
#  {'title': 'Python Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556105'},
#  {'title': 'Senior Python Engineer - CIB Rates Products',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557545'},
#  {'title': 'Software Engineer, Associate (Java/Python)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558189'},
#  {'title': 'Senior Devops Engineer (Python scripting)',
#   'company': 'Basware',
#   'location': 'Chandigarh, India',
#   'apply_link': 'https://stackoverflow.com/jobs/483223'},
#  {'title': 'Senior Python Data Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556079'},
#  {'title': 'VP Python Engineering Manager (Securities Services)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557849'},
#  {'title': 'Experienced Python Software Developer for our Partner ADSPERT (Berlin or remote)',
#   'company': 'solute GmbH',
#   'location': 'Berlin, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/547853'},
#  {'title': 'Data Engineer (Python, SQL)',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'Chicago, IL',
#   'apply_link': 'https://stackoverflow.com/jobs/526406'},
#  {'title': 'Python Software Engineer- Network Support',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557928'},
#  {'title': 'Developer Technology Engineer - Test Automation (C++ / Python / Jenkins)',
#   'company': 'Imagination Technologies',
#   'location': 'Kings Langley, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/543473'},
#  {'title': 'Senior Python Developer - Risk as a Service',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556383'},
#  {'title': 'Softwareentwickler*in Python (w/m/d) - Schwerpunkt Webservices',
#   'company': 'IONOS SE',
#   'location': 'Karlsruhe, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/545352'},
#  {'title': 'Python Linux Specialist Software Engineer',
#   'company': 'Canonical',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/459775'},
#  {'title': 'Cloud Software Engineer (Java / Python) - Vice President - Flexible working',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557508'},
#  {'title': 'Site Reliability Engineer - Associate - Python, AWS/GCP - Flexible Working',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557177'},
#  {'title': '(Senior) Python Developer (m/f/d)',
#   'company': 'tribe29 GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/526671'},
#  {'title': 'Analytics Python Developer - CIB Securities Services Technology',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556919'},
#  {'title': 'Python Engineering Manager - VP - Securities Services',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557892'},
#  {'title': 'CIB - Quantitative Research - Market Risk - Associate - Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557828'},
#  {'title': 'VP Python Engineering Manager (Securities Services)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557718'},
#  {'title': 'Cloud Engineer (Python and/or Java)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556063'},
#  {'title': 'Associate Equity Athena Intraday Risk (Python, React/TS)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555396'},
#  {'title': 'Site Reliability Engineer (SRE)- Java / Python / Linux Production / Operations /...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/556412'},
#  {'title': 'Junior IoT Developer (M/W/D) Python, C++',
#   'company': 'VISPIRON CHARGE-V GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/548810'},
#  {'title': 'DevOps System Engineer / Software Developer (w/m/d)  Linux, Java und/oder Python, Golang',
#   'company': 'DENIC eG',
#   'location': 'Frankfurt, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/550207'},
#  {'title': 'Python Developer',
#   'company': 'Zyte (formerly Scrapinghub)',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/513698'},
#  {'title': 'Développeur-euse Fullstack (Python/Flask)',
#   'company': 'Fintel SAS',
#   'location': 'Marseille, France',
#   'apply_link': 'https://stackoverflow.com/jobs/465113'},
#  {'title': 'Python Software Engineer (Linux, Security)',
#   'company': 'diconium group',
#   'location': 'Stuttgart, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/556429'},
#  {'title': 'HA Proxy-Java/Python Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/555014'},
#  {'title': 'Senior Python Developer - Django Rest Framework',
#   'company': 'n.exchange',
#   'location': 'Lisbon, Portugal',
#   'apply_link': 'https://stackoverflow.com/jobs/554539'},
#  {'title': 'Python Developer - Securities Services Technology: Analytics',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557146'},
#  {'title': 'Python and/or Java, Cloud Technical Lead - Product Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/556846'},
#  {'title': 'Senior Python Engineer - Base Metals Team Lead',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558233'},
#  {'title': 'Senior Cloud Developer - AWS / Cloud Foundry / Java / Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'apply_link': 'https://stackoverflow.com/jobs/555405'},
#  {'title': 'Python Software Engineer - Athena Trade & Risk Services - Inbound STP - VP - CIB',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556347'},
#  {'title': 'Lead Software Engineer - Python Focus Big Loop Systems (m/f/d)',
#   'company': 'CARIAD',
#   'location': 'Ingolstadt, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/547925'},
#  {'title': 'Senior Python Engineer - Athena Trade & Risk Services - Instrument & Lifecycle Group -...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558321'},
#  {'title': 'Node.js Developer (Remote)',
#   'company': 'Soshace LLC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555481'},
#  {'title': 'React or Angular Front-end developer (Remote)',
#   'company': 'Soshace LLC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555480'},
#  {'title': 'Enthusiastic developers for small informal software company',
#   'company': 'Black Cow Technology',
#   'location': 'Oxford, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/503556'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/460037'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Hamburg, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/521823'},
#  {'title': 'Arista Networks is hiring Front End Engineer for Dublin office(JS, React+Redux)',
#   'company': 'Arista Networks, Inc',
#   'location': 'Dublin, Ireland',
#   'apply_link': 'https://stackoverflow.com/jobs/482910'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Hamburg, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/521823'},
#  {'title': 'Cloud Automation Engineer',
#   'company': 'tribe29 GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/547843'},
#  {'title': 'DevOps Engineer with interesting scale up challenges',
#   'company': 'Channable',
#   'location': 'Utrecht, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/500253'},
#  {'title': 'Full Stack Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/552987'},
#  {'title': 'Analyste solution/ Chef de projet déploiement Smart O&M (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/548602'},
#  {'title': 'Product Owner Smart O&M (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/554454'},
#  {'title': 'Senior Frontend Engineer | Angular or React | Barcelona',
#   'company': 'Dynatrace',
#   'location': 'Barcelona, Spain',
#   'apply_link': 'https://stackoverflow.com/jobs/546676'},
#  {'title': 'QA Analyst (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/528279'},
#  {'title': 'Senior Java Engineer | Barcelona',
#   'company': 'Dynatrace',
#   'location': 'Barcelona, Spain',
#   'apply_link': 'https://stackoverflow.com/jobs/546675'},
#  {'title': 'Engineering Manager (Frontend - JS React)',
#   'company': 'uSwitch',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/546667'},
#  {'title': 'Senior Full-stack Web Developer',
#   'company': 'F-Secure',
#   'location': 'Poznań, Poland',
#   'apply_link': 'https://stackoverflow.com/jobs/526479'},
#  {'title': 'Senior Full-stack Web Developer',
#   'company': 'F-Secure',
#   'location': 'Basingstoke, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/535566'},
#  {'title': 'Sr. Software Engineer - Virtual Intelligence Team',
#   'company': 'Flashpoint',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555310'},
#  {'title': 'Android Developer',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552308'},
#  {'title': 'Experienced Front-end Developer',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552301'},
#  {'title': 'Sr. Software Engineer - Managed Intelligence',
#   'company': 'Flashpoint',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555311'},
#  {'title': 'iOS Developers',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552307'},
#  {'title': 'Penetration Tester - Cyber Security',
#   'company': 'F-Secure',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/554863'},
#  {'title': 'Senior Data Scientist / Data Engineer',
#   'company': 'F-Secure',
#   'location': 'Poznań, Poland',
#   'apply_link': 'https://stackoverflow.com/jobs/538605'},
#  {'title': 'C++ developer in Berlin. 120 000 euro per year',
#   'company': 'think-cell',
#   'location': 'Berlin, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/36832'},
#  {'title': 'Full-Stack Software Engineer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530982'},
#  {'title': 'iOS Developer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530984'},
#  {'title': 'Android Developer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530799'},
#  {'title': 'Technical Lead - Data Event Platform',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530983'}]

# %% [markdown]
# ## CSV

# %%
import csv

def save_to_file(jobs):
    file = open("jobs.csv", mode="w",encoding='utf-8-sig',newline='')
    writer = csv.writer(file)
    writer.writerow(['title', 'company', 'location', 'link'])
    for job in jobs:
        writer.writerow(list(job.values()))
    return

# %% [markdown]
# ## Main

# %%
def main():
    indeed_jobs = get_indeed_jobs()
    so_jobs = get_so_jobs()
    jobs = indeed_jobs + so_jobs
    save_to_file(jobs)
    
    return jobs
    
main()
# Out:
# Scrapping Indeed Page : 0
# Scrapping Indeed Page : 1
# Scrapping Indeed Page : 2
# Scrapping Indeed Page : 3
# Scrapping Indeed Page : 4
# Scrapping StackOverflow Page : 0
# Scrapping StackOverflow Page : 1
# Scrapping StackOverflow Page : 2
# Scrapping StackOverflow Page : 3
# Scrapping StackOverflow Page : 4
# Scrapping StackOverflow Page : 5
# Scrapping StackOverflow Page : 6
# Scrapping StackOverflow Page : 7
# Scrapping StackOverflow Page : 8
# [{'Title': 'Python Developer',
#   'Company': 'Shuup Commerce Inc',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f9534ae0091f5310&from=web&vjs=3'},
#  {'Title': 'Backend Python Engineer',
#   'Company': 'Play Magnus',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c27f1c0f6f92cb2c&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'ShipHero',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1ef36fc836615b49&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer',
#   'Company': 'Double River Investments Limited',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bb1cf2320fd7fc69&from=web&vjs=3'},
#  {'Title': 'PYTHON DEVELOPER',
#   'Company': 'Pythonwise',
#   'Location': 'Seattle, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1a20a1c56fb7df73&from=web&vjs=3'},
#  {'Title': 'JUNIOR PYTHON DEVELOPER',
#   'Company': 'Solutions Resource',
#   'Location': 'Bellevue, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ad2bbe549fe4881c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Nexient',
#   'Location': 'Ann Arbor, MI 48108+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=37b2d4933fb25f5f&from=web&vjs=3'},
#  {'Title': 'Junior Python Developer',
#   'Company': 'GTS',
#   'Location': 'New York, NY 10022 (Midtown area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=71acc67a281f6038&from=web&vjs=3'},
#  {'Title': 'Junior Frontend Engineer',
#   'Company': 'The Veloz Group',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=be8ebda8ac2ae04f&from=web&vjs=3'},
#  {'Title': 'Python Software Engineering Teaching Assistant (Part-Time)',
#   'Company': 'Hackbright Academy',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cc10e115d1ed386e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'ESO',
#   'Location': 'Belcamp, MD',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=605b7c6764f51598&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Go8IT',
#   'Location': 'Plainsboro, NJ',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cb88227c76653ec9&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Outside Online',
#   'Location': 'Boulder, CO',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=896f0683f822304e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Highbrow-Tech',
#   'Location': 'Bellevue, WA+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=70912d7ae92ee088&from=web&vjs=3'},
#  {'Title': 'Desarrollador Backend Python',
#   'Company': 'Seeconds',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d0eb1294325cb3f1&from=web&vjs=3'},
#  {'Title': 'PYTHON/PhP SOFTWARE ENGINEER - Contract',
#   'Company': 'InspiHER Tech',
#   'Location': 'Indiana•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a145a678281087dc&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'eMoney Advisor',
#   'Location': '+9 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cf07a7088aaddbd6&from=web&vjs=3'},
#  {'Title': 'Entry Level Business Analyst-Remote',
#   'Company': 'Agama Solutions',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6f6a1c18da31655b&from=web&vjs=3'},
#  {'Title': 'PYTHON DEVELOPER',
#   'Company': 'OC10',
#   'Location': 'Charlotte, NC 28202 (Downtown Charlotte area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f26b8209c93fdd28&from=web&vjs=3'},
#  {'Title': 'Data Analyst- Spring 2022',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=de5d4f8bf8cd486d&from=web&vjs=3'},
#  {'Title': 'Remote Operations & Support Specialist',
#   'Company': 'Netflix',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a67febf94f1a5207&from=web&vjs=3'},
#  {'Title': 'Python Developer Anywhere',
#   'Company': 'Santex Group',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=040f2c487a3dd6d3&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Saraca Solutions',
#   'Location': 'Harrisburg, PA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7a7f0d6cdbec9856&from=web&vjs=3'},
#  {'Title': 'Python Developer-Reactjs',
#   'Company': 'SmarTek21, LLC',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=034026350a31dc8e&from=web&vjs=3'},
#  {'Title': 'Data Engineer (Python, Pyspark, Airflow, AWS)',
#   'Company': 'Nexient',
#   'Location': 'Ann Arbor, MI 48108+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6ef270d4c698a818&from=web&vjs=3'},
#  {'Title': 'Python Engineer - Remote, Full Time',
#   'Company': 'Bluelight Consulting',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9a698878b37e8e50&from=web&vjs=3'},
#  {'Title': 'Python Developer-1',
#   'Company': 'TIAA',
#   'Location': 'New York State+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b736f44252e1d179&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Sara Technologies',
#   'Location': 'San Diego, CA 92127',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=07cc59a85ae4d228&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Moove-it',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=30d2deae65d78d38&from=web&vjs=3'},
#  {'Title': 'Acoustics and Vibration Engineer I (NX)',
#   'Company': 'Gulfstream Aerospace Corporation',
#   'Location': 'Savannah, GA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=84aabceb26b29595&from=web&vjs=3'},
#  {'Title': 'Software Developer – Entry Level',
#   'Company': 'Grant Street Group',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b8bfec599e550f11&from=web&vjs=3'},
#  {'Title': 'Software Engineer- JS and Python',
#   'Company': 'SAP',
#   'Location': 'Bellevue, WA 98004 (Downtown area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2a2fdb6c6567f9c1&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Nuvento systems',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f2beba2d5640fd15&from=web&vjs=3'},
#  {'Title': 'Python Tester',
#   'Company': 'Accenture',
#   'Location': 'Redmond, WA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ee4976f2befef230&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Luxoft',
#   'Location': '+3 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=43cce086e1acd9a1&from=web&vjs=3'},
#  {'Title': 'Backend Python Engineer',
#   'Company': 'Numerator',
#   'Location': 'United States+10 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0d0b756b6441580c&from=web&vjs=3'},
#  {'Title': 'Experienced AWS Python Contractor',
#   'Company': 'stackbuilders',
#   'Location': 'New York, NY 10016 (Flatiron District area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7a6eb7709512853c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Value Info Tech',
#   'Location': 'Phoenix, AZ',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2fa1acf7705f32ea&from=web&vjs=3'},
#  {'Title': 'Senior Software Engineer (Back End - Python)',
#   'Company': 'Nearpod',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=92076d82b5b242ce&from=web&vjs=3'},
#  {'Title': 'Jr. Python Developer',
#   'Company': 'Kibo Commerce',
#   'Location': 'Dallas, TX 75201',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5ccd82b0221de315&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Snap IT Solutions',
#   'Location': 'Houston, TX 77099 (Alief area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0e10fe734c597c75&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Python (Entry-level)',
#   'Company': 'Kernel',
#   'Location': 'Culver City, CA 90232 (Jefferson area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bba24995ad8bfe29&from=web&vjs=3'},
#  {'Title': 'Sr. Python Engineer',
#   'Company': 'Highbrow-Tech',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b3082332444a0831&from=web&vjs=3'},
#  {'Title': 'Python Software Engineer - Remote',
#   'Company': 'DXC Technology',
#   'Location': 'Tampa, FL+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3caadc51357c5314&from=web&vjs=3'},
#  {'Title': 'Python, R Developer',
#   'Company': 'TCS',
#   'Location': 'Indianapolis, IN+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=312ea84743ff9ffb&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Novogradac & Company',
#   'Location': 'Portland, OR+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d2273b9ea4656f60&from=web&vjs=3'},
#  {'Title': 'Junior Engineer',
#   'Company': 'wpromote',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21ebe479a0b1ab2e&from=web&vjs=3'},
#  {'Title': 'Student Worker Part-time',
#   'Company': 'Wiley',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a7f73c389b5a704&from=web&vjs=3'},
#  {'Title': 'Senior Software Engineer (Python)',
#   'Company': 'EAB',
#   'Location': 'Birmingham, AL 35203+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a31c36e906eb13da&from=web&vjs=3'},
#  {'Title': 'Entry Level Software Developer',
#   'Company': 'Property Matrix',
#   'Location': 'Burbank, CA 91502 (Burbank Center area)+8 locations•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c91423d2223633c7&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Alertus',
#   'Location': 'Baltimore, MD 21202 (Inner Harbor area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cc72811ec0f43eda&from=web&vjs=3'},
#  {'Title': 'Web Engineer',
#   'Company': 'Airship',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=df6ccc4b8fbe8e8b&from=web&vjs=3'},
#  {'Title': 'Senior DevOps/SRE Engineer (Can work remotely)',
#   'Company': 'First American',
#   'Location': 'Folsom, CA 95630+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5ddd8a9361bbd9f8&from=web&vjs=3'},
#  {'Title': 'Senior ETL Developer (Python)',
#   'Company': 'Tista Science and Technology Corporation',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4583823af072236a&from=web&vjs=3'},
#  {'Title': 'Data Analyst',
#   'Company': 'Disney Streaming',
#   'Location': 'Santa Monica, CA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3ce68832dc2b5674&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Cumming Group',
#   'Location': 'San Francisco, CA 94111 (Financial District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=89e87dee7366d3b3&from=web&vjs=3'},
#  {'Title': 'Junior Readypipe Engineer I',
#   'Company': 'Yipit Inc.',
#   'Location': 'New York, NY+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6f2b8e2826281709&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Congruent Info-Tech',
#   'Location': 'Bellevue, WA 98007 (Lake Hills area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d3bed7cda41d9f8f&from=web&vjs=3'},
#  {'Title': 'Experienced Python/Django Contractor',
#   'Company': 'stackbuilders',
#   'Location': 'New York, NY 10016 (Flatiron District area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3ca8847c8187fe73&from=web&vjs=3'},
#  {'Title': 'Junior Python Developer',
#   'Company': 'Haynes Futures LLC',
#   'Location': 'Lorton, VA 22079',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=211996a23c2e5a66&from=web&vjs=3'},
#  {'Title': 'Software Developer, Python',
#   'Company': 'Vertical Knowledge',
#   'Location': 'Chagrin Falls, OH•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=621f947d91e7edd3&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'States United Democracy Center',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b166f8d88c2bcfa9&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'OMBU',
#   'Location': 'Portland, OR 97214 (Buckman area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d13b06d1113de40c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Sparibis',
#   'Location': 'Orlando, FL•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3612eb64bce6b034&from=web&vjs=3'},
#  {'Title': 'Jr. DevOps Engineer',
#   'Company': 'SkyHive Technologies Inc.',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a83943b190d2465c&from=web&vjs=3'},
#  {'Title': 'Python Application Developer (13844)',
#   'Company': 'Baer Group',
#   'Location': 'Alexandria, VA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=dd24745835022a3d&from=web&vjs=3'},
#  {'Title': 'Python Engineer - GS Accelerate',
#   'Company': 'Goldman Sachs',
#   'Location': 'Dallas, TX 75201 (Arts District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=801b64da973be520&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'New Jersey Institute of Technology',
#   'Location': 'Newark, NJ 07102 (Central Business District area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b75382f204d97cd8&from=web&vjs=3'},
#  {'Title': 'Jr. Python Developer',
#   'Company': 'Futrend Technology, Inc.',
#   'Location': 'Rockville, MD 20852',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5e3410c1d37f8e00&from=web&vjs=3'},
#  {'Title': 'Frontend Developer',
#   'Company': 'Red Acre',
#   'Location': 'Saint Julian, SC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46e5de74893924a9&from=web&vjs=3'},
#  {'Title': 'Software Engineer (Python)',
#   'Company': 'Sure',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e8b9807be9d1933e&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Python',
#   'Company': 'Backstage',
#   'Location': 'New York, NY•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2814f981b67e8b0b&from=web&vjs=3'},
#  {'Title': 'Entry Level Software Developer (Python)',
#   'Company': 'Columbus Technologies',
#   'Location': 'Pasadena, CA 91101 (West Central area)•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=6c38d6f6235a4fdd&from=web&vjs=3'},
#  {'Title': 'Python Developer (Fullstack)',
#   'Company': 'Konviere Corporation',
#   'Location': 'Leawood, KS',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=213ef23aef1e09fd&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Infogen Labs',
#   'Location': 'Valencia, CA 91355',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b7b5a7c1d1027d10&from=web&vjs=3'},
#  {'Title': 'Frontend Engineer, University Graduate - 2022 Start',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7423e56c5d5a069d&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Taflink Care',
#   'Location': 'Dallas, TX•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e589a87aed9e899f&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Junior',
#   'Company': 'Booz Allen Hamilton',
#   'Location': 'McLean, VA 22102+38 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=77a4c865b43ba0ec&from=web&vjs=3'},
#  {'Title': 'Algorithms Engineer',
#   'Company': 'Double River Investments Limited',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b8876bb1eba675ff&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer (Junior)',
#   'Company': 'Nexient',
#   'Location': 'Columbus, OH+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a1a2a840cfa23f90&from=web&vjs=3'},
#  {'Title': 'Software Engineer (Backend)',
#   'Company': 'Textio',
#   'Location': 'Seattle, WA 98104+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e711a7b12acdcaef&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Capgemini',
#   'Location': 'Burbank, CA+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=921379330a10ad90&from=web&vjs=3'},
#  {'Title': 'Online Coding Instructor (Remote)',
#   'Company': 'CodeCombat',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21ffebdf3906d3a6&from=web&vjs=3'},
#  {'Title': 'Systems Modeling Engineer',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a184ec203496dbac&from=web&vjs=3'},
#  {'Title': 'Python Software Development Engineer',
#   'Company': 'Reynolds and Reynolds',
#   'Location': 'Austin, TX 73301 (St Edwards area)+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4cd3307fd2fb5343&from=web&vjs=3'},
#  {'Title': 'GIS Technician',
#   'Company': 'Flo Analytics',
#   'Location': 'Seattle, WA+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b5e9951b5f0dfff4&from=web&vjs=3'},
#  {'Title': 'Lead Python Engineer',
#   'Company': 'S&P Global',
#   'Location': 'Lansing, MI 48901+45 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9d24af4c2937ade7&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Mati',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ad23e3098da93091&from=web&vjs=3'},
#  {'Title': 'Data Scientist - Entry Level',
#   'Company': 'Numerdox',
#   'Location': 'Sacramento, CA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3dde0133818987f0&from=web&vjs=3'},
#  {'Title': 'Economist - Full Time Opportunities 2022',
#   'Company': 'Wayfair',
#   'Location': 'Boston, MA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3f53429744bc60a9&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Fusion Genius',
#   'Location': 'Alameda, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=374a0913cfa1f9f8&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'SugarCRM',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0b05c2ae25b651c4&from=web&vjs=3'},
#  {'Title': 'Ground Software — Associate Engineer (Summer 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a0ce5b3529fdd4b0&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Advaiya',
#   'Location': 'Bellevue, WA 98007 (Overlake area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9ccb06a74de52829&from=web&vjs=3'},
#  {'Title': 'Sr. Systems Engineer',
#   'Company': "Aaron's",
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a5f9ae893deba38c&from=web&vjs=3'},
#  {'Title': 'Python Engineer - Banking Platform Team',
#   'Company': 'Avant',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7f97b256c3c7e391&from=web&vjs=3'},
#  {'Title': 'Associate Data Engineer (SQL, Cognos, Python)',
#   'Company': 'Travelers',
#   'Location': 'Saint Paul, MN+6 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cd4214a1630c5904&from=web&vjs=3'},
#  {'Title': 'CS152 Introduction to Python Programming',
#   'Company': 'Park University Adjuncts',
#   'Location': 'San Antonio, TX 78236+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b1fa32e276038be3&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'magnitude',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0579faf2b17d7b9d&from=web&vjs=3'},
#  {'Title': 'Programming Staff Writer',
#   'Company': 'Valnet Freelance',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=18806c0298c50194&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'The Oakleaf Group',
#   'Location': 'Washington, DC 20010 (Columbia Heights area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1f466da47bdedea7&from=web&vjs=3'},
#  {'Title': 'Entry-Level Test Engineer',
#   'Company': 'BOEING',
#   'Location': 'Smithfield, PA+7 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=be0585fd4414d72b&from=web&vjs=3'},
#  {'Title': 'Data Scientist & Eng’r.',
#   'Company': 'SLEEP NUMBER',
#   'Location': 'Minneapolis, MN',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f31ebba5005f2755&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Python',
#   'Company': 'SureSwift Capital',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=08da37621c642f55&from=web&vjs=3'},
#  {'Title': 'Site Reliability Engineer - TikTok',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+38 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46ce5c48a3dee160&from=web&vjs=3'},
#  {'Title': '2022 Associate Data Scientist',
#   'Company': 'T. Rowe Price',
#   'Location': 'New York, NY+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ded25292899dd88d&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Saama Technologies Inc',
#   'Location': 'Bridgewater, NJ 08807',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=88a47b061b02935b&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'Wayne State University',
#   'Location': 'Detroit, MI',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7780e19564c00c07&from=web&vjs=3'},
#  {'Title': 'Python Developer - US',
#   'Company': 'Perceptive Analytics',
#   'Location': 'Houston, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=09b67070d526895b&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Cowbell Cyber Inc.',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d761077ec64c4aae&from=web&vjs=3'},
#  {'Title': 'Backend Software Engineer-TikTok',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+16 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=523fdbe809b6c2f2&from=web&vjs=3'},
#  {'Title': 'Entry-Level Computer Engineer',
#   'Company': 'Opal Kelly',
#   'Location': 'Portland, OR 97223',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a2e8830485cc2dd9&from=web&vjs=3'},
#  {'Title': 'Python Backend Developer (Remote)',
#   'Company': 'Parlance',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c2437828c44a5ef9&from=web&vjs=3'},
#  {'Title': 'Middle/Senior Python Developer',
#   'Company': 'ScienceSoft USA Corporation',
#   'Location': 'McKinney, TX 75070',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=483f2eac5b38d2e8&from=web&vjs=3'},
#  {'Title': 'Middle Python Developer',
#   'Company': 'AgileEngine',
#   'Location': 'Grow, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f38bbe4b9c599f58&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Kinect',
#   'Location': 'El Segundo, CA 90245',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c6a0e156fd8d9f08&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer',
#   'Company': 'SPECTRIO LLC',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=320e0ca0515f2896&from=web&vjs=3'},
#  {'Title': 'Platform Engineer (Remote)',
#   'Company': 'Cargill',
#   'Location': 'Hopkins, MN 55343•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=abc44d18f8b5b926&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Stier Solutions',
#   'Location': 'Westlake Village, CA 91361',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b2de55596c3a1f9e&from=web&vjs=3'},
#  {'Title': 'Site Reliablity Engineer',
#   'Company': 'American Eagle Outfitters',
#   'Location': 'Pennsylvania',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3bd5978a37576d97&from=web&vjs=3'},
#  {'Title': 'Software Engineer',
#   'Company': 'Inspirato',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0b3cc43a09c8e3f4&from=web&vjs=3'},
#  {'Title': 'Software Analyst Apprentice',
#   'Company': 'Apprenti',
#   'Location': 'Milwaukee, WI',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=72e8b026db557a82&from=web&vjs=3'},
#  {'Title': 'Developer (Remote)',
#   'Company': 'The Hartford',
#   'Location': 'Texas•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=50995584da0eeb17&from=web&vjs=3'},
#  {'Title': 'Associate, YouTube',
#   'Company': 'YouTube',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a19d5d6e71bffeee&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Convazant',
#   'Location': 'Sunnyvale, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3bd86e0ab712b364&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Python',
#   'Company': 'Kandji',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0a8e299b63defaa8&from=web&vjs=3'},
#  {'Title': 'Marketing & Sales Transformation Data Scientist',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c06e6776bec13016&from=web&vjs=3'},
#  {'Title': 'Network Engineer (with Python Scripting)',
#   'Company': 'Pinnacle Group',
#   'Location': 'Plano, TX+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fee44d88e55ab5e0&from=web&vjs=3'},
#  {'Title': '2021',
#   'Company': 'Chicago Transit Authority',
#   'Location': 'Chicago, IL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4f26544963a8ddec&from=web&vjs=3'},
#  {'Title': 'Senior Full-stack Software Engineer - Javascript / Python /...',
#   'Company': 'Flexbox',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a82777950654f98&from=web&vjs=3'},
#  {'Title': 'Junior Full Stack Engineer',
#   'Company': 'InnovaSystems International, LLC',
#   'Location': 'San Diego, CA 92108 (Mission Valley East area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2b2cd03c5b901051&from=web&vjs=3'},
#  {'Title': 'Python Dev / Analyst',
#   'Company': 'Fuego Leads',
#   'Location': 'Columbus, OH 43215 (Downtown area)•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=71da39d9833d51ad&from=web&vjs=3'},
#  {'Title': 'Backend Engineer, Perception',
#   'Company': 'Snapchat',
#   'Location': 'Los Angeles, CA 90291 (Venice area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ae4f23b48d0d4026&from=web&vjs=3'},
#  {'Title': 'Python Data Engineer',
#   'Company': 'Intone Networks',
#   'Location': '+4 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a282c9a20dc750af&from=web&vjs=3'},
#  {'Title': 'Research Engineer Co-op',
#   'Company': 'Motorola Solutions',
#   'Location': 'Somerville, MA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fb907d3882a0540f&from=web&vjs=3'},
#  {'Title': 'Backend Engineer',
#   'Company': 'Sila Inc.',
#   'Location': 'Portland, OR 97204+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=aed5f7a2e8779c56&from=web&vjs=3'},
#  {'Title': 'Python Developer - US Bank',
#   'Company': 'Globant',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e239b1dd44713ead&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Dyno Nobel',
#   'Location': 'Salt Lake City, UT 84121',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8a7cc0dd2929e87e&from=web&vjs=3'},
#  {'Title': 'Senior React Developer',
#   'Company': 'eMoney Advisor',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=cac29f5a382ee440&from=web&vjs=3'},
#  {'Title': 'Full-Stack Python Software Developer',
#   'Company': 'Advanced Energy Economy',
#   'Location': '+3 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=170985c7d039ee10&from=web&vjs=3'},
#  {'Title': 'Entry-Level Software Engineer',
#   'Company': 'Motorola Solutions',
#   'Location': 'Schaumburg, IL+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=841ef5765d47f4c3&from=web&vjs=3'},
#  {'Title': 'Senior Data Scientist',
#   'Company': 'Schnucks',
#   'Location': 'St. Louis, MO 63146',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8fd43c7ca95087dd&from=web&vjs=3'},
#  {'Title': 'Junior Backend Engineer',
#   'Company': 'AlphaFlow',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a189a6c81fbcd33b&from=web&vjs=3'},
#  {'Title': 'DATA ANALYST',
#   'Company': 'InspiHER Tech',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4842f3e5cde55a12&from=web&vjs=3'},
#  {'Title': 'Junior DevOps Engineer',
#   'Company': 'Deloitte',
#   'Location': 'Mechanicsburg, PA 17050+107 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a9066c895a1041a9&from=web&vjs=3'},
#  {'Title': 'Sr. Backend Engineer - Python (Remote)',
#   'Company': 'Getaround',
#   'Location': 'San Francisco, CA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=748ed3c27f46ca17&from=web&vjs=3'},
#  {'Title': 'Power BI Developer',
#   'Company': 'West Advanced Technologies (WATI)',
#   'Location': 'Rancho Cordova, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8205adb5e07e9abd&from=web&vjs=3'},
#  {'Title': 'JR. Engineer',
#   'Company': 'Nickelodeon Animation',
#   'Location': 'Burbank, CA 91502 (Burbank Center area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46df9ed5428cd34c&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Clairvoyant',
#   'Location': 'Chandler, AZ 85226+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c863b057044219e8&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Quality',
#   'Company': 'Benchling',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c9f2e404687688ff&from=web&vjs=3'},
#  {'Title': 'Senior Data Scientist',
#   'Company': 'Schnucks',
#   'Location': 'St. Louis, MO 63146',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8fd43c7ca95087dd&from=web&vjs=3'},
#  {'Title': 'Software Developer (Entry Level)',
#   'Company': 'UltiSat',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0ae90fabaf5100df&from=web&vjs=3'},
#  {'Title': 'Software Engineer I',
#   'Company': 'IQVIA',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1f65fb5dbbe79c84&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Kibo Commerce',
#   'Location': 'Dallas, TX 75201',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=31915b12b32bc7a9&from=web&vjs=3'},
#  {'Title': 'DATA ANALYST',
#   'Company': 'InspiHER Tech',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4842f3e5cde55a12&from=web&vjs=3'},
#  {'Title': 'Power BI Developer',
#   'Company': 'West Advanced Technologies (WATI)',
#   'Location': 'Rancho Cordova, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8205adb5e07e9abd&from=web&vjs=3'},
#  {'Title': 'Python Software Engineer',
#   'Company': '3M',
#   'Location': 'Austin, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=dd76b213daa9e99f&from=web&vjs=3'},
#  {'Title': 'BI Manager - Digital Marketing',
#   'Company': 'Seer Interactive',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e2cf5a34833d0cac&from=web&vjs=3'},
#  {'Title': 'System Development Engineer – AWS Config, AWS Config',
#   'Company': 'Amazon.com Services LLC',
#   'Location': 'Seattle, WA+126 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=afb982d5d9e99619&from=web&vjs=3'},
#  {'Title': 'Entry Software Engineer',
#   'Company': 'Datavant',
#   'Location': 'California•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=792868e0104b4562&from=web&vjs=3'},
#  {'Title': 'Python Developer - Remote',
#   'Company': 'CentralSquare Technologies',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a8d66acff1b1e381&from=web&vjs=3'},
#  {'Title': 'Software Quality Assurance Engineer',
#   'Company': 'OnlineMedEd',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=50f16bbe30d00820&from=web&vjs=3'},
#  {'Title': 'Sr. Backend Engineer - Python (Remote)',
#   'Company': 'Getaround',
#   'Location': 'San Francisco, CA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=748ed3c27f46ca17&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer',
#   'Company': 'Alloy',
#   'Location': 'New York, NY•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=813829bb6c109643&from=web&vjs=3'},
#  {'Title': 'Java/Python Developer ( Remote)',
#   'Company': 'General Dynamics Information Technology',
#   'Location': 'United States•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0d5ca036a014c5b7&from=web&vjs=3'},
#  {'Title': 'IT Sr Data Scientist',
#   'Company': 'Save-A-Lot',
#   'Location': 'Saint Ann, MO 63074',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46709c4a0f3d76b9&from=web&vjs=3'},
#  {'Title': 'Python and/or C++ Software Engineer',
#   'Company': 'JPMorgan Chase Bank, N.A.',
#   'Location': 'New York, NY+8 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3a5cbba15c31e2c1&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer, MLOps',
#   'Company': 'Lucid Motors',
#   'Location': 'Newark, CA 94560+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=22b32552f979ef4e&from=web&vjs=3'},
#  {'Title': 'Python with AWS Developer',
#   'Company': 'Hash Technologies',
#   'Location': 'Atlanta, GA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9bf965d9d2d4f2a5&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Haneke Design',
#   'Location': 'Tampa, FL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=542b21736b6bca61&from=web&vjs=3'},
#  {'Title': 'SLAM and Perception Engineer',
#   'Company': 'Adaviv',
#   'Location': 'Somerville, MA 02143',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8415a52c6ef4b687&from=web&vjs=3'},
#  {'Title': 'MAC SYSTEM ENGINEER',
#   'Company': 'Central Michigan University',
#   'Location': 'Mount Pleasant, MI',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=835357769b3e0ecc&from=web&vjs=3'},
#  {'Title': 'Deep Learning Engineer/Scientist, Autopilot',
#   'Company': 'Tesla',
#   'Location': 'Palo Alto, CA+4 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9f10697d88ff0253&from=web&vjs=3'},
#  {'Title': 'AWS/Python Developer',
#   'Company': 'Accenture',
#   'Location': 'Hartford, CT 06103 (Downtown area)+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=c04de165c70aead5&from=web&vjs=3'},
#  {'Title': 'Python Engineer',
#   'Company': 'Gelber Group LLC',
#   'Location': 'Chicago, IL 60654 (Near North area)•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8fdaed7e8a5d913f&from=web&vjs=3'},
#  {'Title': 'Software Engineer - Python (BTU Analytics)',
#   'Company': 'FactSet Research Systems',
#   'Location': 'Lakewood, CO+7 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ed21b2e227f9aa61&from=web&vjs=3'},
#  {'Title': 'Robotic Systems Engineer',
#   'Company': 'Greenzie',
#   'Location': 'Atlanta, GA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=aa3aa1d1cdfd1490&from=web&vjs=3'},
#  {'Title': 'Software Engineer',
#   'Company': 'Wolfram',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=ef7b5a6fbb9f1f3e&from=web&vjs=3'},
#  {'Title': 'Fellow, Baseball Research & Development',
#   'Company': 'Cleveland Indians - Baseball Operations',
#   'Location': 'Ohio•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=3b702780b7916f79&from=web&vjs=3'},
#  {'Title': 'Jr. Developer',
#   'Company': 'Deloitte',
#   'Location': 'Los Angeles, CA 90013 (Downtown area)+68 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=dab818dcfc6bae7b&from=web&vjs=3'},
#  {'Title': 'Propulsion — Associate Engineer (Spring 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b1060fd97370fbb6&from=web&vjs=3'},
#  {'Title': 'Machine Learning Engineer',
#   'Company': 'Lenovo',
#   'Location': 'Chicago, IL+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d0fde70ad6a4ceee&from=web&vjs=3'},
#  {'Title': 'Software Development Engineer I',
#   'Company': 'MasterCard',
#   'Location': 'Arlington, VA+7 locations•Temporarily Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1b22cc29086e833c&from=web&vjs=3'},
#  {'Title': 'CG Layout Artist - Monsters at Work',
#   'Company': 'Disney Television Animation',
#   'Location': 'Glendale, CA (Grand Central area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=27a24ac46c92f42e&from=web&vjs=3'},
#  {'Title': 'Research Assistant',
#   'Company': 'Columbia University',
#   'Location': 'New York, NY+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a59d83d3f61b849f&from=web&vjs=3'},
#  {'Title': 'Software Quality & Customer Experience Engineer',
#   'Company': 'Hewlett Packard Enterprise',
#   'Location': 'Fort Collins, CO 80521+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=9da9fef5fe09e501&from=web&vjs=3'},
#  {'Title': 'Profesor/a Data Science',
#   'Company': 'Coderhouse',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=46b3175e11d65f40&from=web&vjs=3'},
#  {'Title': 'Entry Level Systems Engineer',
#   'Company': 'BAE Systems',
#   'Location': 'San Diego, CA 92127 (Rancho Bernardo area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=290fa21bf9cf0110&from=web&vjs=3'},
#  {'Title': 'Junior Software Engineer, DevOps',
#   'Company': 'Ping Identity',
#   'Location': 'Denver, CO 80202 (Central Business District area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=427b723d95f8bf4b&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Fults & Associates',
#   'Location': 'Grapevine, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=724d43dd753723a7&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Palnar Transmedia',
#   'Location': 'United States',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=fdb5a4e060506720&from=web&vjs=3'},
#  {'Title': 'L1 Support - NORAM - Python Developer',
#   'Company': 'Jade Global',
#   'Location': 'San Jose, CA 95110 (North San Jose area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=7650e6bff00fbe96&from=web&vjs=3'},
#  {'Title': 'System Administrator',
#   'Company': '1st Light Energy',
#   'Location': 'Manteca, CA 95336',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d5d89849c0eaea34&from=web&vjs=3'},
#  {'Title': 'Senior Full Stack Python Developer (13794)',
#   'Company': 'Baer Group',
#   'Location': 'Washington, DC•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f038292e08467b86&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer (Remote)',
#   'Company': 'cloudteam',
#   'Location': 'Jacksonville, FL+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4dd5d1fe3064d4e0&from=web&vjs=3'},
#  {'Title': 'Senior Data Engineer',
#   'Company': 'Betterment LLC',
#   'Location': '+1 locationRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=acc0ef87f83723f2&from=web&vjs=3'},
#  {'Title': 'Senior Python Developer',
#   'Company': 'Extreme Engineering Solutions',
#   'Location': 'Verona, WI 53593',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=daf07c3b8f869f77&from=web&vjs=3'},
#  {'Title': 'People Analytics Partner',
#   'Company': 'Netflix',
#   'Location': 'Los Angeles, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=79c852a11001e519&from=web&vjs=3'},
#  {'Title': 'Software Engineer, University Graduate - 2022 Start',
#   'Company': 'TikTok',
#   'Location': 'Seattle, WA+65 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=21cc96f8ed47d56d&from=web&vjs=3'},
#  {'Title': 'Administrateur Système et Réseau H/F',
#   'Company': 'Extia',
#   'Location': 'Rochelle, LA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5b17029136a74c5b&from=web&vjs=3'},
#  {'Title': 'Systems Engineer',
#   'Company': 'Snapchat',
#   'Location': 'Los Angeles, CA 90291 (Venice area)',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=364cf0f9d722572d&from=web&vjs=3'},
#  {'Title': 'Entry level Data Engineer',
#   'Company': 'Certilytics',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e19d25beb10c61ac&from=web&vjs=3'},
#  {'Title': 'Full Stack Developer',
#   'Company': 'Underdog.io',
#   'Location': 'New York, NY+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2df0564df7756395&from=web&vjs=3'},
#  {'Title': 'Python Developer (100% Remote)',
#   'Company': 'Denken Solutions Inc',
#   'Location': 'Alabama+2 locations•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=a60bb97c2e2d2ae1&from=web&vjs=3'},
#  {'Title': 'Trainee Software Engineer RRUS/928/2021',
#   'Company': 'EMIDS',
#   'Location': 'Franklin, TN 37064 (McEwen area)+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0cb511651e086582&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Quip',
#   'Company': 'Salesforce',
#   'Location': '+77 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8caabd819729b588&from=web&vjs=3'},
#  {'Title': 'Systems Programmer / Analyst',
#   'Company': 'Indiana University',
#   'Location': 'Bloomington, IN+1 location',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=8ee506627f792237&from=web&vjs=3'},
#  {'Title': 'Python developer',
#   'Company': 'VAUXOO',
#   'Location': 'Colima, GA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=f7669fcbd77ecd11&from=web&vjs=3'},
#  {'Title': 'Analytics Engineer',
#   'Company': 'Outside Online',
#   'Location': 'Boulder, CO•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d1f21d4024e3fb5e&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Swan Software Solutions',
#   'Location': 'Carmel, IN',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=32eaa9e1e80e8c5d&from=web&vjs=3'},
#  {'Title': 'Software Engineer',
#   'Company': 'Hulu',
#   'Location': 'Santa Monica, CA+6 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=eafa191adae2c646&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Ivy Tech Solutions inc',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4acadd569ee3fb58&from=web&vjs=3'},
#  {'Title': 'Test Development Engineer',
#   'Company': 'Lenovo',
#   'Location': 'Morrisville, NC',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e84c3d80383cd0bd&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Avani Systems',
#   'Location': 'Newark, DE',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=2adef6dc99e86686&from=web&vjs=3'},
#  {'Title': 'Python Bootcamp Prep Instructor (Part-Time)',
#   'Company': 'Hackbright Academy',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d90877b5c3795182&from=web&vjs=3'},
#  {'Title': 'Python Developer with AWS',
#   'Company': 'JPMorgan Chase Bank, N.A.',
#   'Location': 'Jersey City, NJ+28 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e34af623c9f44fb1&from=web&vjs=3'},
#  {'Title': 'Fullstack Engineer (Carve Systems)',
#   'Company': 'iVision',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=1250a0d52245eada&from=web&vjs=3'},
#  {'Title': 'Biomechanics Analyst, Baseball Research & Development',
#   'Company': 'Cleveland Indians - Baseball Operations',
#   'Location': 'Ohio•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=42420b58615467c7&from=web&vjs=3'},
#  {'Title': 'Chargé de projets H/F',
#   'Company': 'CA Indosuez Wealth (Group)',
#   'Location': 'Miami, FL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=128e1dcdcf0c1c6e&from=web&vjs=3'},
#  {'Title': 'Frontend Engineer',
#   'Company': 'Kyte',
#   'Location': 'San Francisco, CA+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=43d9c34f432dc4f1&from=web&vjs=3'},
#  {'Title': 'Data Scientist, Media Innovations',
#   'Company': 'The New York Times',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=56dfa4fb5edc37c4&from=web&vjs=3'},
#  {'Title': 'Test Automation Engineer',
#   'Company': 'Kpler',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=0c7cc111c5a7ae8d&from=web&vjs=3'},
#  {'Title': 'Python/ ETL Tester',
#   'Company': 'Intone Networks',
#   'Location': 'Austin, TX',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=085a7de8ddf9c330&from=web&vjs=3'},
#  {'Title': 'Analyst, DIG Growth (Games)',
#   'Company': 'The New York Times',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b929a38986a9bd98&from=web&vjs=3'},
#  {'Title': 'Front-End Engineer',
#   'Company': 'SAMBA TV',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=92efc35257c9a49d&from=web&vjs=3'},
#  {'Title': 'Entry Level Web Developer',
#   'Company': 'Motorola Solutions',
#   'Location': 'Schaumburg, IL',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=370f3572b77f7a75&from=web&vjs=3'},
#  {'Title': 'Graduate Data Science, Analyst I - August 2022 - Seattle',
#   'Company': 'Expedia.com',
#   'Location': 'Seattle, WA 98119 (Queen Anne area)+12 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=722e513c7e657593&from=web&vjs=3'},
#  {'Title': 'Python Developer - Back End',
#   'Company': 'Deloitte',
#   'Location': 'Rosslyn, VA 22209 (Radnor-Ft Myer Heights area)+126 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=63823d6ee3ca9c19&from=web&vjs=3'},
#  {'Title': 'UX Engineer, Front End, Early Career',
#   'Company': 'Google',
#   'Location': 'San Francisco, CA+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bce1cc9db3680333&from=web&vjs=3'},
#  {'Title': 'Entry Level Data Scientist: 2022',
#   'Company': 'IBM',
#   'Location': 'Research Triangle Park, NC 27709+2 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=d9dc2b2ff8863e63&from=web&vjs=3'},
#  {'Title': 'Data & BI Engineer',
#   'Company': 'Fashion Group',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5c7305bc749d20da&from=web&vjs=3'},
#  {'Title': 'Python Development Lead (13843)',
#   'Company': 'Baer Group',
#   'Location': 'Alexandria, VA•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=02acd56c3c900923&from=web&vjs=3'},
#  {'Title': 'Video Platform Engineer (Herndon, VA)',
#   'Company': 'Pexip',
#   'Location': 'Herndon, VA 20171',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=271155ce0a012751&from=web&vjs=3'},
#  {'Title': 'Software Engineer, Machine Learning',
#   'Company': 'Benchling',
#   'Location': '+2 locationsRemote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=b129ad391a71ef83&from=web&vjs=3'},
#  {'Title': 'Radio Hardware — Associate Engineer (Spring/Summer 2022)',
#   'Company': 'Astranis',
#   'Location': 'San Francisco, CA',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=e75569e6b749dfef&from=web&vjs=3'},
#  {'Title': 'Middle Python Developer',
#   'Company': 'Mobilunity',
#   'Location': 'United States+1 location•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=523fde45ae4cfa9a&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'ING',
#   'Location': 'New York, NY',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=40802b7c00af44d8&from=web&vjs=3'},
#  {'Title': 'Python Developer',
#   'Company': 'Morgan Stanley',
#   'Location': 'New York, NY+3 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=84c7ba71c316a022&from=web&vjs=3'},
#  {'Title': 'Junior Java /.Net /Python Developer',
#   'Company': 'Infosys',
#   'Location': 'Groton, CT•Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4f16edb2c700c56a&from=web&vjs=3'},
#  {'Title': 'Full Stacker Developer (100% Remote US-based)',
#   'Company': 'Cricket Media Services, Inc.',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=bd7ef81ae80b8131&from=web&vjs=3'},
#  {'Title': 'Research Data Analyst',
#   'Company': 'Daily Kos',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=5cf6da7c0b03f782&from=web&vjs=3'},
#  {'Title': 'Operations Python Developer',
#   'Company': 'Hudson River Trading',
#   'Location': 'Austin, TX+5 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=4a01bb894b3c68e9&from=web&vjs=3'},
#  {'Title': 'Economist',
#   'Company': 'Amazon.com Services LLC',
#   'Location': 'Seattle, WA+15 locations',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=983318b8073d1250&from=web&vjs=3'},
#  {'Title': 'Senior Manager, Data & Analytics',
#   'Company': 'Nutrien Ltd.',
#   'Location': 'Remote',
#   'ApplyLnk': 'https://www.indeed.com/viewjob?jk=48498880ee6fe877&from=web&vjs=3'},
#  {'Title': 'Backend Developer (Python/MongoDB)',
#   'Company': 'Irisidea TechSolutions Pvt Ltd',
#   'Location': 'Remote',
# ...
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558334'},
#  {'title': 'Fullstack Developer (Python/React)',
#   'company': 'We Got POP Ltd',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/525267'},
#  {'title': 'Softwareentwickler* Python bei Feynsinn',
#   'company': 'EDAG Group',
#   'location': 'Garching bei München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/529037'},
#  {'title': 'Python Software Engineer (Athena Rates Technology)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556089'},
#  {'title': 'Python Developer/ Trading Systems Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522467'},
#  {'title': 'Software Engineer (Java, Python) - Product Tooling',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/555919'},
#  {'title': 'Python Developer/ Data Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522466'},
#  {'title': 'Python Automation Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'apply_link': 'https://stackoverflow.com/jobs/557539'},
#  {'title': 'Python Data Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557686'},
#  {'title': 'Senior Python Engineer - Athena Trade & Risk Services - Instrument & Lifecycle Group -...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558321'},
#  {'title': 'Python Alteryx Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557793'},
#  {'title': 'Python Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556105'},
#  {'title': 'Senior Python Engineer - Athena Trade & Risk Services - Instrument & Lifecycle Group -...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/558321'},
#  {'title': 'Software Developer Python / Linux (m/w/d)',
#   'company': 'Univention GmbH',
#   'location': 'Bremen, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/551134'},
#  {'title': 'Software Engineering - Java Developer (with Python, Linux and Oracle/SQL DB exp)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557956'},
#  {'title': 'Developer Technology Engineer - Test Automation (C++ / Python / Jenkins)',
#   'company': 'Imagination Technologies',
#   'location': 'Kings Langley, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/543473'},
#  {'title': 'Real time Data Engineer (Python/C++)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/558334'},
#  {'title': 'Experienced Python Software Developer for our Partner ADSPERT (Berlin or remote)',
#   'company': 'solute GmbH',
#   'location': 'Berlin, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/547853'},
#  {'title': 'Softwareentwickler* Python bei Feynsinn',
#   'company': 'EDAG Group',
#   'location': 'Garching bei München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/529037'},
#  {'title': 'Python Software Engineer (Athena Rates Technology)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556089'},
#  {'title': 'Senior .Net Developer for ML, Computer Vision and Python Algorithm development',
#   'company': 'MapLarge',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/165235'},
#  {'title': 'Python Developer/ Data Engineer',
#   'company': 'Huxley Banking & Financial ServicesviaHuxley (US)',
#   'location': 'New York, NY',
#   'apply_link': 'https://stackoverflow.com/jobs/522466'},
#  {'title': 'Python Automation Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Columbus, OH',
#   'apply_link': 'https://stackoverflow.com/jobs/557539'},
#  {'title': 'Fullstack Developer (Python/React)',
#   'company': 'We Got POP Ltd',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/525267'},
#  {'title': '(Senior) Python Developer (m/f/d)',
#   'company': 'tribe29 GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/526671'},
#  {'title': 'Python Alteryx Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/557793'},
#  {'title': 'Python Site Reliability Engineer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556105'},
#  {'title': 'Python Software Engineer (Cloud/Data Science)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/557670'},
#  {'title': 'Mobile CI/CD Build Engineer Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556045'},
#  {'title': 'Data Engineer Lead - Java Python',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Wilmington, DE',
#   'apply_link': 'https://stackoverflow.com/jobs/557688'},
#  {'title': 'Software Engineering - Python or other OOP',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557970'},
#  {'title': 'Python Developer',
#   'company': 'Etiometry',
#   'location': 'Boston, MA',
#   'apply_link': 'https://stackoverflow.com/jobs/504970'},
#  {'title': 'Python Software Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556844'},
#  {'title': 'Senior Python Data Engineer - AI Solutions',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556079'},
#  {'title': 'Cloud Software Engineer - Python - VP',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557858'},
#  {'title': 'Senior Python Engineer - Back End - Take Charge Of Our In-House CMS',
#   'company': 'Immersive Labs',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/552495'},
#  {'title': 'Python Software Engineer (Cloud)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555388'},
#  {'title': 'Python/Java Infrastructure Developer - Data Protection',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Bournemouth, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557068'},
#  {'title': 'Software Engineering - Python or other OOP',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557970'},
#  {'title': 'Fullstack Cloud Engineer (Python/React/AWS)',
#   'company': 'Montash',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/556128'},
#  {'title': 'Mobile CI/CD Build Engineer Python Developer',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Plano, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556045'},
#  {'title': 'Associate Equity Athena Intraday Risk (Python, React/TS)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/555396'},
#  {'title': 'Cloud Engineer (Python and/or Java)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Houston, TX',
#   'apply_link': 'https://stackoverflow.com/jobs/556063'},
#  {'title': 'DevOps System Engineer / Software Developer (w/m/d)  Linux, Java und/oder Python, Golang',
#   'company': 'DENIC eG',
#   'location': 'Frankfurt, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/550207'},
#  {'title': 'Senior Python Engineer - Back End - Take Charge Of Our In-House CMS',
#   'company': 'Immersive Labs',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/552495'},
#  {'title': 'Senior IoT Developer (M/W/D/) Python, C++',
#   'company': 'VISPIRON CHARGE-V GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/524044'},
#  {'title': 'IoT / Java, Python Entwickler (w/m/d) - bundesweit & Homeoffice',
#   'company': 'objective partner AG',
#   'location': 'Weinheim, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/550882'},
#  {'title': 'Site Reliability Engineer (SRE)- Java / Python / Linux Production / Operations /...',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/556412'},
#  {'title': 'Python Engineering Manager - VP - Securities Services',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557892'},
#  {'title': 'Senior Software Engineer, Integration QA, Python',
#   'company': 'Canonical',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/519661'},
#  {'title': 'Python and/or Java, Cloud Technical Lead - Product Engineering',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'Jersey City, NJ',
#   'apply_link': 'https://stackoverflow.com/jobs/556846'},
#  {'title': 'VP Python Engineering Manager (Securities Services)',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557718'},
#  {'title': 'Data Engineer (m/f) (SQL, Python, R, Java)',
#   'company': 'RIAG DIGITAL',
#   'location': 'Wien, Austria',
#   'apply_link': 'https://stackoverflow.com/jobs/376577'},
#  {'title': 'Développeur-euse Fullstack (Python/Flask)',
#   'company': 'Fintel SAS',
#   'location': 'Marseille, France',
#   'apply_link': 'https://stackoverflow.com/jobs/465113'},
#  {'title': 'Python Developer - Securities Services Technology: Analytics',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/557146'},
#  {'title': 'Senior .Net Developer for ML, Computer Vision and Python Algorithm development',
#   'company': 'MapLarge',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/165235'},
#  {'title': 'Python Software Engineer - Athena Trade & Risk Services - Inbound STP - VP - CIB',
#   'company': 'JPMorgan Chase Bank, N.A.',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/556347'},
#  {'title': 'Node.js Developer (Remote)',
#   'company': 'Soshace LLC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555481'},
#  {'title': 'React or Angular Front-end developer (Remote)',
#   'company': 'Soshace LLC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555480'},
#  {'title': 'Enthusiastic developers for small informal software company',
#   'company': 'Black Cow Technology',
#   'location': 'Oxford, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/503556'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/460037'},
#  {'title': 'Java/Spring Developer (Remote)',
#   'company': 'Soshace LLC',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555482'},
#  {'title': 'C++ developer in Berlin. 120 000 euro per year',
#   'company': 'think-cell',
#   'location': 'Berlin, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/36832'},
#  {'title': 'Node.js Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Hamburg, Germany',
#   'apply_link': 'https://stackoverflow.com/jobs/521823'},
#  {'title': 'Cloud Automation Engineer',
#   'company': 'tribe29 GmbH',
#   'location': 'München, Deutschland',
#   'apply_link': 'https://stackoverflow.com/jobs/547843'},
#  {'title': 'Full Stack Engineer (m/f/d)',
#   'company': 'Fashion Cloud',
#   'location': 'Amsterdam, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/552987'},
#  {'title': 'Analyste solution/ Chef de projet déploiement Smart O&M (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/548602'},
#  {'title': 'DevOps Engineer with interesting scale up challenges',
#   'company': 'Channable',
#   'location': 'Utrecht, Netherlands',
#   'apply_link': 'https://stackoverflow.com/jobs/500253'},
#  {'title': 'Senior Frontend Engineer | Angular or React | Barcelona',
#   'company': 'Dynatrace',
#   'location': 'Barcelona, Spain',
#   'apply_link': 'https://stackoverflow.com/jobs/546676'},
#  {'title': 'Product Owner Smart O&M (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/554454'},
#  {'title': 'Arista Networks is hiring Front End Engineer for Dublin office(JS, React+Redux)',
#   'company': 'Arista Networks, Inc',
#   'location': 'Dublin, Ireland',
#   'apply_link': 'https://stackoverflow.com/jobs/482910'},
#  {'title': 'QA Analyst (H/F)',
#   'company': 'ENGIE Digital',
#   'location': 'Paris, France',
#   'apply_link': 'https://stackoverflow.com/jobs/528279'},
#  {'title': 'Senior Java Engineer | Barcelona',
#   'company': 'Dynatrace',
#   'location': 'Barcelona, Spain',
#   'apply_link': 'https://stackoverflow.com/jobs/546675'},
#  {'title': 'Engineering Manager (Frontend - JS React)',
#   'company': 'uSwitch',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/546667'},
#  {'title': 'Senior Full-stack Web Developer',
#   'company': 'F-Secure',
#   'location': 'Poznań, Poland',
#   'apply_link': 'https://stackoverflow.com/jobs/526479'},
#  {'title': 'Senior Full-stack Web Developer',
#   'company': 'F-Secure',
#   'location': 'Basingstoke, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/535566'},
#  {'title': 'Sr. Software Engineer - Virtual Intelligence Team',
#   'company': 'Flashpoint',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555310'},
#  {'title': 'Android Developer',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552308'},
#  {'title': 'Experienced Front-end Developer',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552301'},
#  {'title': 'Sr. Software Engineer - Managed Intelligence',
#   'company': 'Flashpoint',
#   'location': 'No office location',
#   'apply_link': 'https://stackoverflow.com/jobs/555311'},
#  {'title': 'iOS Developers',
#   'company': 'F-Secure',
#   'location': 'Helsinki, Finland',
#   'apply_link': 'https://stackoverflow.com/jobs/552307'},
#  {'title': 'Penetration Tester - Cyber Security',
#   'company': 'F-Secure',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/554863'},
#  {'title': 'Senior Data Scientist / Data Engineer',
#   'company': 'F-Secure',
#   'location': 'Poznań, Poland',
#   'apply_link': 'https://stackoverflow.com/jobs/538605'},
#  {'title': 'Full-Stack Software Engineer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530982'},
#  {'title': 'iOS Developer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530984'},
#  {'title': 'Android Developer',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530799'},
#  {'title': 'Technical Lead - Data Event Platform',
#   'company': 'Marks & Spencer',
#   'location': 'London, UK',
#   'apply_link': 'https://stackoverflow.com/jobs/530983'}]
